# %%
import json
import os
import yaml
from typing import Dict, List, Any, Optional
from datetime import datetime
from collections import defaultdict
from pprint import pprint



def move_working_dir_to_repo_root(repo_name="orgsync"):
    """
    Move the current working directory to the root of the repository.
    """
    current_dir = os.getcwd()
    while os.path.basename(current_dir).lower() != repo_name:
        current_dir = os.path.dirname(current_dir)
    os.chdir(current_dir)
    print("Current working directory: ", os.getcwd())

move_working_dir_to_repo_root(repo_name="orgsync")
# Out:
# Current working directory:  c:\Users\dec2g\GitHub\OrgSync

# %%
# Determine the directory where this script is located
# script_directory = os.path.dirname(os.path.abspath(__file__))

# Define the base path and the file paths to combine
input_path = "data/raw/all_scraped/"

file_paths = {
    "organisations": os.path.join(input_path, "gtr/scraped/2024_07/organisations.json"),
    "projects": os.path.join(input_path, "gtr/scraped/2024_07/projects.json"),
    "persons": os.path.join(input_path, "gtr/scraped/2024_07/persons.json"),
}

schema_paths = {
    "organisations": os.path.join(input_path, "gtr/scraped/schemas/organisation.json"),
    "projects": os.path.join(input_path, "gtr/scraped/schemas/project.json"),
    "persons": os.path.join(input_path, "gtr/scraped/schemas/person.json"),
}

# %%
class SchemaProcessor:
    def __init__(self, schema_path: str):
        """Initialize processor with a schema file path."""
        self.schema = self._load_json(schema_path)
        self.processed_fields = set()
        self.nested_arrays = {}
        self.links = {}
        self._analyze_schema(self.schema)

    @staticmethod
    def _load_json(filepath: str) -> Dict:
        """Load JSON data from file."""
        with open(filepath, 'r') as f:
            return json.load(f)

    def _analyze_schema(self, schema: Dict, parent_path: str = "") -> None:
        """Recursively analyze schema to identify nested structures and links."""
        if not isinstance(schema, dict):
            return

        # Handle items in arrays
        if "items" in schema:
            self._analyze_schema(schema["items"], parent_path)
            return

        # Process properties
        properties = schema.get("properties", {})
        for field, details in properties.items():
            current_path = f"{parent_path}.{field}" if parent_path else field
            
            if details.get("type") == "array":
                array_items = details.get("items", {})
                if array_items.get("type") == "object":
                    self.nested_arrays[current_path] = array_items.get("properties", {})
            
            elif details.get("type") == "object":
                self._analyze_schema(details, current_path)

            # Track fields that are required
            if field in schema.get("required", []):
                self.processed_fields.add(field)

            # Special handling for links
            if field == "links":
                self.links[current_path] = details

    def process_data(self, data: Dict, entity_type: str) -> Dict:
        """Process a single data entry according to schema."""
        processed = {}
        
        # Basic fields
        for field in self.processed_fields:
            if field in data:
                # Handle timestamps
                if field == "created":
                    processed[field] = self._convert_timestamp(data[field])
                else:
                    processed[field] = data[field]

        # Process nested arrays
        for path, properties in self.nested_arrays.items():
            parts = path.split(".")
            current_data = data
            for part in parts:
                current_data = current_data.get(part, {})
                if not current_data:
                    break

            if current_data:
                if isinstance(current_data, list):
                    processed[parts[-1]] = [
                        {k: item.get(k) for k in properties}
                        for item in current_data
                    ]
                elif isinstance(current_data, dict):
                    processed[parts[-1]] = [
                        {k: v.get(k) for k in properties}
                        for v in current_data.values()
                        if isinstance(v, dict)
                    ]

        # Process links
        if "links" in data and "link" in data["links"]:
            processed["relationships"] = self._process_links(data["links"]["link"], entity_type)

        return processed

    def _process_links(self, links: List[Dict], entity_type: str) -> Dict[str, List[str]]:
        """Process links into categorized relationships."""
        relationships = defaultdict(list)
        
        for link in links:
            rel_type = link.get("rel", "").lower()
            href = link.get("href", "")
            if href:
                entity_id = href.split("/")[-1]
                relationships[rel_type].append({
                    "id": entity_id,
                    "type": rel_type,
                    "start": self._convert_timestamp(link.get("start")),
                    "end": self._convert_timestamp(link.get("end"))
                })
        
        return dict(relationships)

    @staticmethod
    def _convert_timestamp(ms: Optional[int]) -> Optional[str]:
        """Convert millisecond timestamp to ISO format date string."""
        if not ms:
            return None
        return datetime.fromtimestamp(ms/1000).isoformat()

def process_dataset(schema_path: str, data_path: str, entity_type: str) -> List[Dict]:
    """Process an entire dataset using its schema."""
    processor = SchemaProcessor(schema_path)
    raw_data = processor._load_json(data_path)
    
    # Handle both single objects and arrays
    if isinstance(raw_data, list):
        return [processor.process_data(item, entity_type) for item in raw_data]
    return [processor.process_data(raw_data, entity_type)]

def combine_datasets(processed_data: Dict[str, List[Dict]]) -> List[Dict]:
    """Combine processed datasets into a single coherent structure."""
    combined = []
    
    # Start with organizations
    for org in processed_data['organizations']:
        org_record = {
            'organization': {
                'id': org.get('id'),
                'name': org.get('name'),
                'created': org.get('created')
            },
            'relationships': org.get('relationships', {}),
            'projects': [],
            'persons': []
        }
        
        # Add related projects
        project_refs = {
            rel['id'] for rel in org.get('relationships', {}).get('project', [])
        }
        org_record['projects'] = [
            proj for proj in processed_data['projects']
            if proj.get('id') in project_refs
        ]
        
        # Add related persons
        person_refs = {
            rel['id'] for rel in org.get('relationships', {}).get('employee', [])
        }
        org_record['persons'] = [
            person for person in processed_data['persons']
            if person.get('id') in person_refs
        ]
        
        combined.append(org_record)
    
    return combined

# %%
# Define schema and data paths
schemas = {
    'organisations': schema_paths['organisations'],
    'projects': schema_paths['projects'],
    'persons': schema_paths['persons']
}

data_files = {
    'organisations': file_paths['organisations'],
    'projects': file_paths['projects'],
    'persons': file_paths['persons']
}


org_processor = SchemaProcessor(schema_paths['organisations'])

# org_processor._load_json(file_paths['organisations'])

# Process each dataset
# processed_data = {}
# for entity_type, schema_path in schemas.items():
#     pprint(entity_type)
#     pprint(schema_path)
    # processed_data[entity_type] = process_dataset(
    #     schema_path,
    #     data_files[entity_type],
    #     entity_type
    # )

# # Combine datasets
# combined_data = combine_datasets(processed_data)

# # Save results
# with open('combined_data.json', 'w') as f:
#     json.dump(combined_data, f, indent=2)

# combined_data
# Out:
# [{'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/0D5DF2FF-B732-4218-B0E3-4FFBF3DDC906',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/0D0F72CC-0163-47CE-A462-5FDDBA4C1C38',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/0C6849FD-CA2D-49A9-80D4-75F710980208',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/C4059685-9263-44E6-B89A-D8609FCC1360',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/F0E04953-58F2-46FB-9837-3C341A3D3165',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/D9A401D9-6D91-4DA6-9012-7137774B1DD8',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/EC918CE3-4862-4EED-884A-E1AC42C8F46D',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/ADB18319-E0B8-4735-AC8B-59946A4BB9CB',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/DCFE5B2E-2EC2-4AA2-9244-EE252CED60E4',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/1E0BB71C-795B-4D20-B46C-2E618CAC96C0',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/2294E699-BBAC-47CB-9293-6BAC6BED2640',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/A45E2042-8FFF-40EF-B270-15D95481946E',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/096F035D-FAEB-4187-9C63-1DA5337E85B9',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/6C78CAA4-62B1-40BC-AF39-A2949521BEB9',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/E0B948B2-4771-4063-BCF0-2E0B58080049',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/1F792DF3-9B47-41E9-96E6-9F90F754314B',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/963F82CE-27D8-460F-9DB3-D61E8D7380AA',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/A8502FDF-589C-4C08-861E-895C6D1BB126',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/3AE6C680-4967-4B0E-94FF-E1DA2DF79838',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/0A2B35E7-1DCC-48D3-A6BC-14A8C4C4FCA0',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/716EFB49-3F49-4618-850E-2BC9E83679DC',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/18B5E7EF-CF71-4F59-87BB-E7F6DEE92508',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/13A0CD0B-7912-484E-BE83-7A82F703533F',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/F41D42DE-E390-4DA4-BE95-FBBBDB61CBC0',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/F7EC062A-3B31-4C42-9E03-CA013F58242B',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/persons/0CB4A538-AC14-4394-A10F-C9F955033EF3',
#      'rel': 'EMPLOYEE',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '5331B126-3AB4-4412-B56D-00E8F2796556',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/5331B126-3AB4-4412-B56D-00E8F2796556',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'NEWCASTLE CITY COUNCIL',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'C20B6399-DBC6-4523-9C69-946A304A37D7',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'NE1 8QH',
#      'region': 'North East',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/B012B0D9-EEBC-414F-BA4A-8AF2B1898477',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/B0359A89-AE42-4B13-8B85-21671966E3F6',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/persons/951DAD79-185A-4009-B3AE-1717EC2AF063',
#      'rel': 'EMPLOYEE',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '53331120-0290-49FA-A513-0286A214AF7A',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/53331120-0290-49FA-A513-0286A214AF7A',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'VALERANN UK LIMITED',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'AF7F7686-3DE3-475B-BCED-201E39037299',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'MK14 6GD',
#      'region': 'South East',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/6272E5E8-1321-48E3-B91B-63E358F4B4FD',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/34D4F9E9-6C1F-4F86-9A1A-215B89DFA44F',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '77874202-2018-4677-8CFF-0868CD838659',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/77874202-2018-4677-8CFF-0868CD838659',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'Baltic Sea Cultural Centre in Gdansk',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': []}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/86D3E475-E582-4D08-8D13-99CEEFC43E17',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '77908BF8-1B2D-4D26-9119-155100E8B9C5',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/77908BF8-1B2D-4D26-9119-155100E8B9C5',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'Mindray',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '51E6A87A-834A-4596-9054-C2D76E37A389',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'PE29 6FN',
#      'region': 'East of England',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/B6328B17-69B0-4044-B156-0A26D338A5CE',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '7794C645-9CC7-4913-A8DC-103AE0EFDD4B',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/7794C645-9CC7-4913-A8DC-103AE0EFDD4B',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'Democracy International',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '61C06F28-0616-4787-8974-781CD5997724',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': '20814',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/7BFFAA57-86BD-423E-A20E-DE07A97F1366',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/261693D8-75B9-482E-8052-DF9B3AB3B9F7',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/A5C71609-4B9F-4A80-9CC0-D612ABBA8895',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/024FE285-FBD1-4038-9782-3A7FA08939E4',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/19B1184B-4C3A-4847-BAC3-75D166360AE2',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/2316473B-AB62-49AD-BC46-4A4CBC2A680B',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '77A41173-DC2B-4D30-A5E2-0B19BE4B8FD5',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/77A41173-DC2B-4D30-A5E2-0B19BE4B8FD5',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'Wimbledon College of Art',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': []}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/A1026C17-835C-4C5E-848D-C592CCB035E7',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '53474E16-DA35-4007-9F07-1B6C0F32BBF6',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/53474E16-DA35-4007-9F07-1B6C0F32BBF6',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'LICX UK LIMITED',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'A0758586-BC56-405E-AFC4-25D1141A016F',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'HP7 0UT',
#      'region': 'South East',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/DDBC1424-0C1D-43A0-9680-ED7A2966478B',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/248C1BF6-C784-4DAD-B434-3359E849FC1E',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/persons/77F68725-592C-4A80-B09B-369B326AEE94',
#      'rel': 'EMPLOYEE',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '5370084A-BDBF-4A7B-8E02-09B7DE95D01B',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/5370084A-BDBF-4A7B-8E02-09B7DE95D01B',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'PANITEK POWER LIMITED',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'BF0ECC80-3586-416A-9389-D13AF30F1200',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'EC1V 2NX',
#      'region': 'London',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/DD73BF27-0EE7-49D3-A883-6B68BF3FA946',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/96E64EB6-1F2E-48C7-8AD1-093A33E8684A',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '53700B68-0910-469D-A0CB-18A3316DF3F2',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/53700B68-0910-469D-A0CB-18A3316DF3F2',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'Agency for Healthcare Research and Quality',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'B2386A5D-D843-4826-9F82-5A15B35CBAC7',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'Unspecified',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/C34CB6BB-58EC-467B-9835-32DB2BFD03E1',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '537D521C-3D73-458B-A054-196982ADD766',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/537D521C-3D73-458B-A054-196982ADD766',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'CONTROL DEVELOPMENTS (UK) LTD',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'CD7A8595-6D06-412B-A426-9DB133F33427',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'OX29 4PU',
#      'region': 'South East',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/BA986004-AA70-405A-AA51-2EDB3D3C0B62',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/984AC337-3F14-4E0B-802E-C00B2793915A',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/99E40BE4-D1C7-467F-8FEB-E12307A9FA1E',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/BC739729-4972-4EDB-B16F-928728078BDB',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/3456C9C7-CB44-422D-ACD2-BAAEA814B8D5',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/D6971E4B-4DCB-4B37-BBEB-D86BF08E78FB',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/persons/01BEA753-42E4-4851-897A-9B958654945C',
#      'rel': 'EMPLOYEE',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/persons/21E238F9-FF8D-4D1F-9B79-F8FAA394B8B0',
#      'rel': 'EMPLOYEE',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/persons/E34FB1EC-C147-4841-B3F2-C21A9E9C97F6',
#      'rel': 'EMPLOYEE',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/persons/60F878A6-1A67-44D8-9B4A-4A59EA0FDBB2',
#      'rel': 'EMPLOYEE',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/persons/6145512E-62D1-46BC-B1F6-3D852FA8AD36',
#      'rel': 'EMPLOYEE',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/persons/35EB75A3-7D83-4885-8D37-E71028F703B7',
#      'rel': 'EMPLOYEE',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/persons/C1AD50D0-8549-4A52-9317-967DBC5CF908',
#      'rel': 'EMPLOYEE',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '538761FB-F8B6-4799-9ADA-02F4EF15E8B3',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/538761FB-F8B6-4799-9ADA-02F4EF15E8B3',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'University of Santo Tomas',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'DBB48AA5-C1AC-4185-AA01-E2C14BB60D25',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': '1008',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/E9352DB0-7A51-4C08-A0FA-F8C2EBC02BD7',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '538EFD3B-D8AF-4B06-BB0E-122E58E65FEF',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/538EFD3B-D8AF-4B06-BB0E-122E58E65FEF',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'ABERDEEN HARBOUR BOARD',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'E63839C3-E01C-4B32-9368-C6BE932D2EBB',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'AB11 5SS',
#      'region': 'Scotland',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/79ED280E-4A78-445C-AB95-E5D341FFFFB9',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/633142B1-4896-4FCD-8AFD-BBD00B9238C8',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/5416191E-55CD-461E-90A1-C9F8D6D5B644',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '53966061-8B83-46CE-A89B-0742392BBF28',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/53966061-8B83-46CE-A89B-0742392BBF28',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'Daido Steel Co., Ltd.',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': []}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/092E2646-001A-47DF-88BE-4A68B7323EAC',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '5396B4CA-422A-4ACB-88AC-1BF02F1D28D3',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/5396B4CA-422A-4ACB-88AC-1BF02F1D28D3',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'AK INDUSTRIES LIMITED',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '86191FB7-EB42-4889-BA0D-C7C511F3C042',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'HR2 6JQ',
#      'region': 'West Midlands',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/13D6CB96-9A70-426D-A5AE-FC861D3E30C2',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/D933151E-B360-4079-8249-26BEA95D02E8',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/E4D57807-CEB2-4DD8-894F-28072FD6047F',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/1AC61B95-0EE0-4247-8F77-12D464F7FA3A',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/20BA1573-DFAD-483E-BE80-89E261F0465D',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '53976912-3F5A-4744-95C5-064AB2C12A67',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/53976912-3F5A-4744-95C5-064AB2C12A67',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'Joseph Fourier University',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'DED40871-696B-4493-A565-AEE8A1219A43',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'F-38026',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/E7297743-EEDD-499D-B3DF-45AEC1937A2E',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/persons/16B53730-D22D-4CC7-A0ED-91FFB23DE200',
#      'rel': 'EMPLOYEE',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '5398E19C-4A38-4777-9DB1-0224648914E0',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/5398E19C-4A38-4777-9DB1-0224648914E0',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'KOOL ZONE LIMITED',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '304BDD46-8309-44CE-BFA9-783BCB2537C2',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'RG9 1NX',
#      'region': 'South East',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/04310D5A-0058-4EC0-92D3-5606A77AD483',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/F1A45654-606B-43F2-A8AA-8FB284B8570E',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/5EE49DB6-697B-4682-8A40-9E21D45B2BCF',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '53A5E511-5AF1-4968-9003-017A4654CDDF',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/53A5E511-5AF1-4968-9003-017A4654CDDF',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'PERTH AND KINROSS COUNCIL',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'D5CEDF6D-E41C-49F1-8F39-C853E2F9E61D',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'Unknown',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/82EE6ECA-1E33-45D1-857C-521A9515E979',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '53AB545D-9946-4C47-B670-07AA591E9CFF',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/53AB545D-9946-4C47-B670-07AA591E9CFF',
#   'created': 1704709432000,
#   'updated': None,
#   'name': '3D MERCHANDISING LIMITED',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'FCD4F408-2356-4711-9A62-D3B585B672A8',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'BB1 1HW',
#      'region': 'North West',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/0D74B7FD-D8B8-47B6-B146-16C8DF0E2D96',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/68C8945D-A7A4-4356-A925-A61D3D4C3B33',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/7AF16BDC-9096-41C6-A9F2-0B51F922564B',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/983C6D5B-BFA6-4DB4-BCA6-12E22ED3741D',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/persons/9895BD2A-CEF2-476E-8B8E-58B79C935E13',
#      'rel': 'EMPLOYEE',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '53BA34F0-E638-4982-9838-0A95057E307C',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/53BA34F0-E638-4982-9838-0A95057E307C',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'INTERACTIVE SCIENTIFIC LIMITED',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'BBE91572-BE26-433B-97B7-17AE1BA83417',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'BS5 0BY',
#      'region': 'South West',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/51A70496-C7E7-45AF-80D1-E29BF84E0D75',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '53E2A744-ECAB-4EF5-906B-0CE5BC88D892',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/53E2A744-ECAB-4EF5-906B-0CE5BC88D892',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'Harbro',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': []}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/7107D161-B3D8-4757-9E24-641321640A65',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '53EB396D-86D6-493A-B369-050AE65964DC',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/53EB396D-86D6-493A-B369-050AE65964DC',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'STREETBOOK LIMITED',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '29735DAE-8815-4721-8B82-AE86CC84C412',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'Unknown',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/351F5468-E3A4-489D-8902-BC0EE8D48F1C',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': 'C61A8110-0095-4677-B44D-095010520FEE',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/C61A8110-0095-4677-B44D-095010520FEE',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'Cornish Metals (International)',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '4190099D-76B2-4EAE-B20E-042130856177',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'V6C 1H2',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/410DE193-9127-4762-80B8-F6B69E9371AF',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': 'C65374AD-00FC-4195-BDD5-07FB22FDCAFE',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/C65374AD-00FC-4195-BDD5-07FB22FDCAFE',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'Garton Engineering',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'A29567C5-E38C-4CFD-8BED-344EF92FB4A4',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'WS10 9RF',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/7BD7BC8C-9990-4F7F-B6CA-ED9FF55023B0',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': 'C6660A85-06D3-4404-97E4-12ECCDEA6392',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/C6660A85-06D3-4404-97E4-12ECCDEA6392',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'European Heart Network EHN',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': []}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/4B7B5278-F69C-4AD3-8BE0-3D429588E0AE',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': 'C66ED940-54F4-4A72-862F-0FE53B35AB91',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/C66ED940-54F4-4A72-862F-0FE53B35AB91',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'Thermo Fisher (redundant 2)',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'F52287BA-5E69-43C7-85C8-A99DB60A4CCA',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'PA4 9RF',
#      'region': 'Scotland',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/E5D84743-45B5-4CA5-A5A7-386999AB33D5',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/94A6AF82-964B-49CE-BEB0-87B4EFA6211D',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/B6D5B40B-7DDD-44F6-8843-9449C3FE4014',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/223BDC8F-5F8B-42A8-BAA7-9A2D4635CAC5',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': 'C67E7D74-CEE3-48EF-BF9D-17642869D974',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/C67E7D74-CEE3-48EF-BF9D-17642869D974',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'Kennesaw State University',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '7ECA2A79-A967-4327-A6DD-B24F7D7B14B1',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'Unspecified',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/42457AFA-A199-475B-90D8-D08672200C3D',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': 'C6803337-5F06-468F-8C40-0E72569F2A65',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/C6803337-5F06-468F-8C40-0E72569F2A65',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'ESMA Memory Site Museum',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '77C0EAC1-64FC-4B38-91BD-AAEED5D343DB',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': '8151',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/3C3B23A5-F995-477B-A64E-153373C065E4',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': 'C689E969-03F8-4474-87CA-1B328652F1E9',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/C689E969-03F8-4474-87CA-1B328652F1E9',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'Hatfield House',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '54894FFF-7F14-458A-905C-5BC5C6DDE7DA',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'AL9 5NQ',
#      'region': 'East of England',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/E9BFF3E1-8F65-4C1D-8BA1-B460FC2EB09B',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': 'C69C6D0B-7290-42A2-A9DB-01E2A9FEAFE8',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/C69C6D0B-7290-42A2-A9DB-01E2A9FEAFE8',
#   'created': 1704709432000,
#   'updated': None,
#   'name': '7 LAYER SOLUTIONS LIMITED',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '082BC9E6-F563-4915-A85B-F984E4FDBE9A',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'GL50 3DT',
#      'region': 'South West',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/8561D9C4-27D2-44C2-8883-42414619FF43',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/persons/3D0DC5D0-C76C-41C3-9B16-7E26F3C43454',
#      'rel': 'EMPLOYEE',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': 'C6AE248D-B9BC-4699-930A-0B93D8D3D17C',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/C6AE248D-B9BC-4699-930A-0B93D8D3D17C',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'SMARTBOX ASSISTIVE TECHNOLOGY LIMITED',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '586E9061-A110-44A6-839B-86234F531AD4',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'WR14 3HD',
#      'region': 'West Midlands',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/CD954780-BDC3-4B16-A629-61A7C8F66856',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': 'C6CF6DCE-7AF7-491C-9026-08C915D4EF16',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/C6CF6DCE-7AF7-491C-9026-08C915D4EF16',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'PTC Inc.',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '2CD5E2CA-AACA-4986-AB16-A314A51DA478',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': '02210',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/B838A8A2-2FDD-466D-BACB-B6F521C62963',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': 'C6D80C9C-1A93-45D6-B66C-005E80E440D2',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/C6D80C9C-1A93-45D6-B66C-005E80E440D2',
#   'created': 1704709432000,
#   'updated': None,
#   'name': '3D SCANNERS (UK) LIMITED',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '4010E5F4-4D99-4833-B40E-DED7EC8E3338',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'CV1 2TT',
#      'region': 'West Midlands',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/8552BD0E-0C3A-4F4F-8BE3-B7F1E60E2254',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': 'C718246D-BF42-430B-86BE-024554B4012A',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/C718246D-BF42-430B-86BE-024554B4012A',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'Kindling Trust',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': []}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/14ACB6B1-2225-4D1E-B282-70421CEC1566',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': 'C71C7957-CBB3-42A3-BD6F-0E94AED96EFA',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/C71C7957-CBB3-42A3-BD6F-0E94AED96EFA',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'Natural Voice Network',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '7D53CC36-6DF9-49A7-B307-12F2ED1305E9',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'S10 4DP',
#      'region': 'Yorkshire and The Humber',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/719E87FC-5371-467D-B996-5CB18342A89C',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/B3D6EBB9-E344-42BF-AF22-97F33CC5AA28',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/EF7FD39A-1645-402A-ACCB-2731B65C8486',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': 'C735D86D-A45F-45A6-8290-0F5E72793D0E',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/C735D86D-A45F-45A6-8290-0F5E72793D0E',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'University of Puerto Rico',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '0D36811C-5FF8-46F1-BF25-C3DC0E381543',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': '00931-3345',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/698FA0FA-9015-4FA6-926B-3A7A9305BF82',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/ADA279DC-982A-45F2-8FEE-9A8AD27B168A',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/93605F61-F2CE-4E66-94FA-A4A48EE38DA5',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/0B9C4853-B06D-4525-B89A-5553B9354784',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/A5946C19-BA1A-4C4A-90E3-4B682309354F',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/9AD9BEE0-51E6-45CE-803B-FE35B122118C',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/211E6913-8175-45F6-93EF-E53671AB747B',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/A162DBB1-5945-474A-AB50-0E32DDD5DBB4',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': 'C77749C7-2323-4D32-B276-0DFF4D639B7B',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/C77749C7-2323-4D32-B276-0DFF4D639B7B',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'Nova Southeastern University',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'D46ACED1-5B25-44A7-AF48-DDD8044E4FDC',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'FL 33314 7',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/E2F2DB29-708D-4E1E-8245-DDFE4B425185',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/71156D4A-6EFC-4328-B5F3-77A0577D77D9',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': 'C77D1065-12E2-49B1-8E8D-0D77999A644F',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/C77D1065-12E2-49B1-8E8D-0D77999A644F',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'PILKINGTON UNITED KINGDOM LIMITED',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '0C5ACFDA-B21D-47D5-BB95-FDBCFDD8FEBD',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'L40 5UF',
#      'region': 'North West',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/903716C3-B768-4BCD-AF0D-E3C7B785666E',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': 'C78D6FA9-C2C7-4783-86C8-0B048D681EC8',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/C78D6FA9-C2C7-4783-86C8-0B048D681EC8',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'Japan Broadcasting Corporation (Japan)',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '9ACCFBB3-9BAB-402F-B67E-0CC19DD4079C',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'Unspecified',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/E97B4B2F-9452-48C9-9A00-D96056365BCA',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': 'C79A6382-1B21-4B02-99E9-03DB5D8AAFFE',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/C79A6382-1B21-4B02-99E9-03DB5D8AAFFE',
#   'created': 1704709432000,
#   'updated': None,
#   'name': 'Stratford Primary Care Network',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
# ...
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/persons/C326D5DA-958F-4424-A19E-3AEB255E9450',
#      'rel': 'EMPLOYEE',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/persons/E4961243-1DEF-452D-9259-1AF21F4CC8D1',
#      'rel': 'EMPLOYEE',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/persons/8451E15E-C21D-466E-9507-7E5E7FDC9ACB',
#      'rel': 'EMPLOYEE',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '0D68C241-8794-4E1E-A9A9-015364D84F2E',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/0D68C241-8794-4E1E-A9A9-015364D84F2E',
#   'created': 1704709544000,
#   'updated': None,
#   'name': 'Federal University of Rio Grande do Sul',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '34960946-F1CC-48D4-B584-BB656B9E8A01',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': '96201-900',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/4A1D537F-32DD-41FA-AE22-576D8CDCE464',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '0D74635C-F03E-4AAF-B644-226D8DCC5FD7',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/0D74635C-F03E-4AAF-B644-226D8DCC5FD7',
#   'created': 1704709544000,
#   'updated': None,
#   'name': 'Coed Cymru Cyf',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '0D71CA0B-E545-4875-AA94-F4732E94DC22',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'SY16 3PL',
#      'region': 'Wales',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/7CCCF0AA-732B-4A4C-8CA5-6180C6329F58',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '0D74D7E7-8838-4010-B4D6-20419440862A',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/0D74D7E7-8838-4010-B4D6-20419440862A',
#   'created': 1704709544000,
#   'updated': None,
#   'name': 'Scandinavian Studies',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': []}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/442FADFE-CB0E-4835-ADE7-C957E1190029',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/62CDFCEE-2B40-4E65-9431-44171D29A218',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/34E7542D-091A-423F-AF0A-7F383451095D',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '0D7E9C04-E3D9-474C-A514-35584430E1BC',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/0D7E9C04-E3D9-474C-A514-35584430E1BC',
#   'created': 1704709544000,
#   'updated': None,
#   'name': 'SELEX Galileo',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '36AE2443-C44C-4552-AC31-4F7BB3160E95',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'SO15 0EG',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/F0543BE4-7C56-413E-B363-20E428815923',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '0D9C4CCA-BF02-45BF-9EC9-157DD539DBA8',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/0D9C4CCA-BF02-45BF-9EC9-157DD539DBA8',
#   'created': 1704709544000,
#   'updated': None,
#   'name': 'Department of Social Promotion',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'D2A0D63D-F958-4C2B-9854-FCD067021663',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': '40015-010',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/46803468-8C5A-4049-99DF-38E3CF7C8EA1',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/6AE9C598-E91F-4B12-8CD7-275979310530',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/12DE3C34-EDCA-4F75-9B4D-30AD9914B370',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/EC1CD84C-49FE-490D-BF63-4F5B24F8A933',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/7C34FB45-9DE0-4B93-A3BD-817785EAC448',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '0DA47DBF-5135-4794-8F7B-203922E8CC28',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/0DA47DBF-5135-4794-8F7B-203922E8CC28',
#   'created': 1704709544000,
#   'updated': None,
#   'name': 'Baker Hughes',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': []}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/1B784027-DE6F-46C0-96E1-32F489611C4E',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/persons/7F14F924-B9CF-4A02-B124-23B00E08D621',
#      'rel': 'EMPLOYEE',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '0DA8D048-99DC-42F8-8079-353167623FD1',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/0DA8D048-99DC-42F8-8079-353167623FD1',
#   'created': 1704709544000,
#   'updated': None,
#   'name': 'ENGINEERING THE BLUE LIMITED',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'C3C6C06B-BE95-47FC-91DC-BBB9362712B2',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'EC1V 4PW',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/3848C54A-C1A5-4CC9-A623-A904B638F581',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '0DBFBC56-6F2F-4487-872F-1415A91E9BD0',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/0DBFBC56-6F2F-4487-872F-1415A91E9BD0',
#   'created': 1704709544000,
#   'updated': None,
#   'name': 'Casa Sollievo della Sofferenza',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'A1B3341F-1DD6-4CB6-9B17-8F86F9E68FEE',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'Unspecified',
#      'region': 'Unknown',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/F9FCEB7C-506B-4D8F-95C6-20147358EF76',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/F1733A4D-214A-464D-AA76-6CE511AE6621',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/48D02D7F-E850-4DFA-B15C-FD1FBDA7BC30',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/97F58EC4-7EB9-4E36-ADE0-09F0F7B3F25F',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/E8689543-1B05-40B2-801B-BF81C5271EB1',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/CF6C254D-A262-4A6A-9E55-4A743643518C',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '0DEBB74B-8AF1-46E9-A32B-2F6696F0C8A4',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/0DEBB74B-8AF1-46E9-A32B-2F6696F0C8A4',
#   'created': 1704709544000,
#   'updated': None,
#   'name': 'HUGH LOWE FARMS LIMITED',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'A9E2300A-F8D5-40B1-B864-D9ACAB9C810E',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'ME18 5NF',
#      'region': 'South East',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/255BE46C-BEBE-41C9-A51F-DEDE52B48E7A',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/AF346DF8-173F-4F3E-83A9-6D76FCC6EB0D',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/CD428A16-3AFE-4F03-8AC1-7E9E5B96E840',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '0DF1AB6F-ED8C-4556-B5E5-185E1C7A3166',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/0DF1AB6F-ED8C-4556-B5E5-185E1C7A3166',
#   'created': 1704709544000,
#   'updated': None,
#   'name': 'Hangzhou Normal University, China',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': []}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/92A2CFE2-B38F-4F8B-9AD0-50ABF355639E',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '0E0CFB89-8124-43AB-ABB1-1B53D24D967F',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/0E0CFB89-8124-43AB-ABB1-1B53D24D967F',
#   'created': 1704709544000,
#   'updated': None,
#   'name': 'ISS GROUP SERVICES LIMITED',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '840FB7FB-282B-4C9C-A885-D13C47581F67',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'M20 4XP',
#      'region': 'North West',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/678682F3-7BCE-4F93-B91A-FB352E3DC70A',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '0E20975F-B515-44A5-8DBC-14389ADAE7DD',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/0E20975F-B515-44A5-8DBC-14389ADAE7DD',
#   'created': 1704709544000,
#   'updated': None,
#   'name': 'Francis Davey',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': '3880259A-929B-4EDC-8AD8-D5762ED6525A',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'N1 6AA',
#      'region': 'London',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/E8DAFE09-C28A-41ED-9196-57389B2427F1',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '0E38EA03-CEA4-4B14-9F87-2BDBFF1207FE',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/0E38EA03-CEA4-4B14-9F87-2BDBFF1207FE',
#   'created': 1704709544000,
#   'updated': None,
#   'name': 'European Speechwriter Network',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'F658DB68-CA1B-4869-9016-5786F7BF653F',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'BH1 4RQ',
#      'region': 'South West',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/60339720-D735-4ACE-996C-68B8CB249256',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/B18D3DAB-73AF-43E6-AB3C-5473F5734DAB',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '0E45F8D0-9BC5-476E-A6EB-19CC4BCCFD4F',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/0E45F8D0-9BC5-476E-A6EB-19CC4BCCFD4F',
#   'created': 1704709544000,
#   'updated': None,
#   'name': "Elizabeth Gaskell's House",
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': [{'links': None,
#      'ext': None,
#      'id': 'C8CF5FCC-7D2A-4B0A-A740-BD4644EE8017',
#      'outcomeid': None,
#      'href': None,
#      'created': 1720391292000,
#      'updated': None,
#      'line1': None,
#      'line2': None,
#      'line3': None,
#      'line4': None,
#      'line5': None,
#      'city': None,
#      'county': None,
#      'postCode': 'M13 9LW',
#      'region': 'North West',
#      'country': None,
#      'type': 'MAIN_ADDRESS'}]}},
#  {'links': {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/0CA7EA82-515F-4CAA-BAF6-7162471C0141',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}},
#     {'href': 'http://gtr.ukri.org/gtr/api/projects/0559F052-045C-4063-8920-9CC630994759',
#      'rel': 'PROJECT',
#      'start': None,
#      'end': None,
#      'otherAttributes': {}}]},
#   'ext': None,
#   'id': '0E52F0E7-5385-4190-8DCE-320D0A7ACA48',
#   'outcomeid': None,
#   'href': 'http://gtr.ukri.org/gtr/api/organisations/0E52F0E7-5385-4190-8DCE-320D0A7ACA48',
#   'created': 1704709544000,
#   'updated': None,
#   'name': 'Iberian and Latin American Studies',
#   'regNumber': None,
#   'website': None,
#   'addresses': {'address': []}},
#  ...]

# %%
raw_data = org_processor._load_json(file_paths['organisations'])

if isinstance(raw_data, list):
    print([org_processor.process_data(item, "organisations") for item in raw_data])
else:
    print([org_processor.process_data(raw_data, "organisations")])
# org_processor.process_data(data=file_paths['organisations'], entity_type="organisations")
