# %% [markdown]
# ## 1. Open GtR Dataset and Expand Nested Fields

# %%
import os, sys, json
import numpy as np
import pandas as pd
import re
import ast
from pprint import pprint

def move_working_dir_to_repo_root(repo_name="orgsync"):
    """
    Move the current working directory to the root of the repository.
    """
    current_dir = os.getcwd()
    while os.path.basename(current_dir).lower() != repo_name:
        current_dir = os.path.dirname(current_dir)
    os.chdir(current_dir)
    print("Current working directory: ", os.getcwd())

move_working_dir_to_repo_root(repo_name="orgsync")
# Out:
# Current working directory:  c:\Users\dec2g\GitHub\OrgSync

# %% [markdown]
# Methods

# %%
def json_to_df(path:str):
    with open(path, 'r') as f:
        data = json.load(f)
    return pd.DataFrame(data)

def df_column_has_unique_values(df: pd.DataFrame, column:str, return_unique_values: bool=True): 
    """
    Prints summary of unique values in each column of the dataframe

    Printed outputs:
        - False: Column has the same value across all rows
        - True: Column has unique values
        - None: Column has unhashable type (e.g. list, dict, etc.)
        - (if return_unique_values=True), all unique values in the column printed
    """
    try:
        unique_values = df[column].unique()
        if len(unique_values) > 1:
            if return_unique_values:
                return unique_values
            else:
                return True
        else:
            return False
    except Exception as e:
        # print(e)
        return None
    
def check_columns_are_unique(df: pd.DataFrame):
    for col in df.columns:
        has_unique = df_column_has_unique_values(df, col, return_unique_values=False)
        if has_unique is not None:
            print(col, f" has unique values: {has_unique}")
        else:
            print(col, f" unhashable type: {df[col].dtype}")


def remove_columns_with_single_unique_value(df: pd.DataFrame):
    """
    Some columns have the same value across all rows. These columns are not useful for analysis.

    This function removes columns that have the same value across all rows.
    """
    for col in df.columns:
        has_unique = df_column_has_unique_values(df, col, return_unique_values=False)
        if has_unique is not None and not has_unique:
            df.drop(col, axis=1, inplace=True)
    return df

# %%
def expand_columns_containing_dictionaries(df, column_name:str):
    """
    Expand columns that contain nested dictionaries into separate columns.

    Structure of the nested dictionary:
    {
        key1:
            [
                {key2: value2},
                ...,
                {keyn: valuen}
            ]
    }

    We will ignore key1, and extract the values of key2, ..., keyn into separate columns.
    """
    df_dicts = df[[column_name]].copy()
    series = df_dicts[column_name]

    def get_series_type(series):
        column_values_type = series.apply(lambda x: type(x)).unique()
        if len(column_values_type) > 1:
            print(f"Column {column_name} contains multiple types: {column_values_type}")
            return None
        else:
            return column_values_type[0]

    def extract_series(df_dicts, column_name):
        new_columns = []
        series = df_dicts[column_name]
        series_type = get_series_type(series)
        if series_type[0] == dict:
            # map each key to a new column and values to the new column
            for key in series[0].keys():
                df_dicts[key] = series.apply(lambda x: x.get(key))
                new_columns.append(key)
        
        if series_type[0] == list:
            all_dicts = all(series.apply(lambda x: all([type(y) == dict for y in x])).to_list())
            if not all_dicts:
                print(f"Column {column_name} contains a list of non-dictionary values.")
                return df_dicts
            else: 
                df_dicts_exploded = df_dicts.explode(column_name)
             
        return df_dicts

# %%
# raw gtr data
gtr_orgs = "data/raw/all_scraped/gtr/scraped/2024_07/organisations.json"
df = json_to_df(gtr_orgs)
df.head()
# Out:
#                                                links   ext  \
# 0  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...  None
# 1  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...  None
# 2  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...  None
# 3  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...  None
# 4  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...  None
#
#                                      id outcomeid  \
# 0  5331B126-3AB4-4412-B56D-00E8F2796556      None
# 1  53331120-0290-49FA-A513-0286A214AF7A      None
# 2  77874202-2018-4677-8CFF-0868CD838659      None
# 3  77908BF8-1B2D-4D26-9119-155100E8B9C5      None
# 4  7794C645-9CC7-4913-A8DC-103AE0EFDD4B      None
#
#                                                 href        created updated  \
# 0  http://gtr.ukri.org/gtr/api/organisations/5331...  1704709432000    None
# 1  http://gtr.ukri.org/gtr/api/organisations/5333...  1704709432000    None
# 2  http://gtr.ukri.org/gtr/api/organisations/7787...  1704709432000    None
# 3  http://gtr.ukri.org/gtr/api/organisations/7790...  1704709432000    None
# 4  http://gtr.ukri.org/gtr/api/organisations/7794...  1704709432000    None
#
#                                    name regNumber website  \
# 0                NEWCASTLE CITY COUNCIL      None    None
# 1                   VALERANN UK LIMITED      None    None
# 2  Baltic Sea Cultural Centre in Gdansk      None    None
# 3                               Mindray      None    None
# 4               Democracy International      None    None
#
#                                            addresses
# 0  {'address': [{'links': None, 'ext': None, 'id'...
# 1  {'address': [{'links': None, 'ext': None, 'id'...
# 2                                    {'address': []}
# 3  {'address': [{'links': None, 'ext': None, 'id'...
# 4  {'address': [{'links': None, 'ext': None, 'id'...

# %%
print(type(df["links"].iloc[0]))

pprint(df["links"].iloc[1])

print(type(df["addresses"].iloc[0]))

pprint(df["addresses"].iloc[1])
# Out:
# <class 'dict'>
# {'link': [{'end': None,
#            'href': 'http://gtr.ukri.org/gtr/api/projects/B012B0D9-EEBC-414F-BA4A-8AF2B1898477',
#            'otherAttributes': {},
#            'rel': 'PROJECT',
#            'start': None},
#           {'end': None,
#            'href': 'http://gtr.ukri.org/gtr/api/projects/B0359A89-AE42-4B13-8B85-21671966E3F6',
#            'otherAttributes': {},
#            'rel': 'PROJECT',
#            'start': None},
#           {'end': None,
#            'href': 'http://gtr.ukri.org/gtr/api/persons/951DAD79-185A-4009-B3AE-1717EC2AF063',
#            'otherAttributes': {},
#            'rel': 'EMPLOYEE',
#            'start': None}]}
# <class 'dict'>
# {'address': [{'city': None,
#               'country': None,
#               'county': None,
#               'created': 1720391292000,
#               'ext': None,
#               'href': None,
#               'id': 'AF7F7686-3DE3-475B-BCED-201E39037299',
#               'line1': None,
#               'line2': None,
#               'line3': None,
#               'line4': None,
#               'line5': None,
#               'links': None,
#               'outcomeid': None,
#               'postCode': 'MK14 6GD',
#               'region': 'South East',
#               'type': 'MAIN_ADDRESS',
#               'updated': None}]}

# %% [markdown]
# # we want to blow up the links and addresses columns
# 1. Input: pandas series with dictionary containing list of dictionaries
#    1. Step 1: Series of dictionaries containing lists of dictionaries
#       1. Each row is: {"key": [{dict}, ... {dict}]}
#       2. We want to create a new for each key in the top level dictionary, with column name = key, and rows = list of dictionaries
#    2. Step 2: Series of lists containing dictionaries
#       1. Each row is [{dict, ..., dict}]
#          1. Addresses:
#             1. For addresses, we can just create new columns for each of the dicts in the list, each dict is a separate field.
#          2. Links:
#             1. Multiple dictionaries in the list with the same fields linking to different publications etc.... So can't just map to new columns.
#    3. Step 3: Dictionary of values
#       1. Each row is {"key": value}
#       2. Transform the series of dictionaries into a dataframe with column name = key and rows = values

# %% [markdown]
# **For addresses:**
# * next just remove any columns that are all Nans

# %%
original_df = df.copy()
original_column = df["addresses"].copy()
original_column.head()
# Out:
# 0    {'address': [{'links': None, 'ext': None, 'id'...
# 1    {'address': [{'links': None, 'ext': None, 'id'...
# 2                                      {'address': []}
# 3    {'address': [{'links': None, 'ext': None, 'id'...
# 4    {'address': [{'links': None, 'ext': None, 'id'...
# Name: addresses, dtype: object

# %%
# step 1: create new columns from keys in dictionary and values in dictionary
# expand dictionary into separate columns
def expand_dictionary_column(df, column_name:str):
    
    original_column = df[column_name].copy()
    # get new columns from dictionary
    new_columns = pd.json_normalize(original_column)

    df_level_one = pd.concat([new_columns, original_column], axis=1)
    return df_level_one

def map_each_dict_in_list_to_new_column(df_expanded, new_col_names):
    """
    Only works for address column
    """
    df_level_one = df_expanded
    col_of_dicts = []
    # go through each new column in level one
    for col in new_col_names:
        if type(df_level_one[col].iloc[0]) == list:
            print("true")
            # move each element of list to separate column
            list_to_cols = pd.json_normalize(df_level_one.copy()[col])
            col_of_dicts.append(list_to_cols)
    expanded_dfs = []
    for series in col_of_dicts:
        column_name = series.columns[0]
        print(f"Expanding column: {column_name}")
        expanded = expand_dictionary_column(series, column_name)
        expanded.drop(column_name, axis=1, inplace=True)
        expanded_dfs.append(expanded)

    expanded_df = pd.concat(expanded_dfs, axis=1)
    level_two = pd.concat([df_level_one, expanded_df], axis=1)
    level_two.drop(new_col_names, axis=1, inplace=True)
    return level_two

def expand_addresses(df):
    """
    Only works for address column
    """
    df_level_one = expand_dictionary_column(df, "addresses")
    new_col_names = [col for col in df_level_one.columns.to_list() if col not in original_df.columns.to_list()]
    print(new_col_names)
    df_level_one.head()
    return map_each_dict_in_list_to_new_column(df_level_one, new_col_names)

df_level_one = expand_dictionary_column(df, "addresses")
new_col_names = [col for col in df_level_one.columns.to_list() if col not in original_df.columns.to_list()]
print(new_col_names)
df_level_one.head()
df_level_two = map_each_dict_in_list_to_new_column(df_level_one, new_col_names)
df_level_two.head()
# Out:
# ['address']
# true
# Expanding column: 0
#                                            addresses  links  ext  \
# 0  {'address': [{'links': None, 'ext': None, 'id'...    NaN  NaN
# 1  {'address': [{'links': None, 'ext': None, 'id'...    NaN  NaN
# 2                                    {'address': []}    NaN  NaN
# 3  {'address': [{'links': None, 'ext': None, 'id'...    NaN  NaN
# 4  {'address': [{'links': None, 'ext': None, 'id'...    NaN  NaN
#
#                                      id  outcomeid  href       created  \
# 0  C20B6399-DBC6-4523-9C69-946A304A37D7        NaN   NaN  1.720391e+12
# 1  AF7F7686-3DE3-475B-BCED-201E39037299        NaN   NaN  1.720391e+12
# 2                                   NaN        NaN   NaN           NaN
# 3  51E6A87A-834A-4596-9054-C2D76E37A389        NaN   NaN  1.720391e+12
# 4  61C06F28-0616-4787-8974-781CD5997724        NaN   NaN  1.720391e+12
#
#    updated  line1  line2  line3  line4  line5  city  county  postCode  \
# 0      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN   NE1 8QH
# 1      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN  MK14 6GD
# 2      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN       NaN
# 3      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN  PE29 6FN
# 4      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN     20814
#
#             region  country          type
# 0       North East      NaN  MAIN_ADDRESS
# 1       South East      NaN  MAIN_ADDRESS
# 2              NaN      NaN           NaN
# 3  East of England      NaN  MAIN_ADDRESS
# 4          Unknown      NaN  MAIN_ADDRESS

# %% [markdown]
# For Links: We want to get the list of dicts as new rows as there are multiple links for a given entry.

# %%
original_df = df.copy()
original_column = df["links"].copy()
original_column.head()
# Out:
# 0    {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
# 1    {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
# 2    {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
# 3    {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
# 4    {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
# Name: links, dtype: object

# %% [markdown]
# Lots of dictionaries for one row of the original dataframe, each with the same fields...

# %%
links_level_one = expand_dictionary_column(df, "links")
# print first row
pprint(links_level_one["link"].iloc[0])
links_level_one.head()
# Out:
# [{'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/0D5DF2FF-B732-4218-B0E3-4FFBF3DDC906',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/0D0F72CC-0163-47CE-A462-5FDDBA4C1C38',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/0C6849FD-CA2D-49A9-80D4-75F710980208',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/C4059685-9263-44E6-B89A-D8609FCC1360',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/F0E04953-58F2-46FB-9837-3C341A3D3165',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/D9A401D9-6D91-4DA6-9012-7137774B1DD8',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/EC918CE3-4862-4EED-884A-E1AC42C8F46D',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/ADB18319-E0B8-4735-AC8B-59946A4BB9CB',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/DCFE5B2E-2EC2-4AA2-9244-EE252CED60E4',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/1E0BB71C-795B-4D20-B46C-2E618CAC96C0',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/2294E699-BBAC-47CB-9293-6BAC6BED2640',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/A45E2042-8FFF-40EF-B270-15D95481946E',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/096F035D-FAEB-4187-9C63-1DA5337E85B9',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/6C78CAA4-62B1-40BC-AF39-A2949521BEB9',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/E0B948B2-4771-4063-BCF0-2E0B58080049',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/1F792DF3-9B47-41E9-96E6-9F90F754314B',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/963F82CE-27D8-460F-9DB3-D61E8D7380AA',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/A8502FDF-589C-4C08-861E-895C6D1BB126',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/3AE6C680-4967-4B0E-94FF-E1DA2DF79838',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/0A2B35E7-1DCC-48D3-A6BC-14A8C4C4FCA0',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/716EFB49-3F49-4618-850E-2BC9E83679DC',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/18B5E7EF-CF71-4F59-87BB-E7F6DEE92508',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/13A0CD0B-7912-484E-BE83-7A82F703533F',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/F41D42DE-E390-4DA4-BE95-FBBBDB61CBC0',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/projects/F7EC062A-3B31-4C42-9E03-CA013F58242B',
#   'otherAttributes': {},
#   'rel': 'PROJECT',
#   'start': None},
#  {'end': None,
#   'href': 'http://gtr.ukri.org/gtr/api/persons/0CB4A538-AC14-4394-A10F-C9F955033EF3',
#   'otherAttributes': {},
#   'rel': 'EMPLOYEE',
#   'start': None}]
#                                                 link  \
# 0  [{'href': 'http://gtr.ukri.org/gtr/api/project...
# 1  [{'href': 'http://gtr.ukri.org/gtr/api/project...
# 2  [{'href': 'http://gtr.ukri.org/gtr/api/project...
# 3  [{'href': 'http://gtr.ukri.org/gtr/api/project...
# 4  [{'href': 'http://gtr.ukri.org/gtr/api/project...
#
#                                                links
# 0  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
# 1  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
# 2  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
# 3  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
# 4  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...

# %% [markdown]
# For now lets just expand out into rows so that we have multiple rows per project

# %%
df = original_df.copy()
df_link_expanded = expand_dictionary_column(df, "links").drop("links", axis=1)
df = pd.concat([df, df_link_expanded], axis=1)
# df['link'] = df['link'].apply(ast.literal_eval)
df_exploded = df.explode('link')

df_exploded.head()
print(len(df_exploded))
print(len(df))
# Out:
# 671161
# 69067

# %%
df_exploded.head()
# Out:
#                                                links   ext  \
# 0  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...  None
# 0  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...  None
# 0  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...  None
# 0  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...  None
# 0  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...  None
#
#                                      id outcomeid  \
# 0  5331B126-3AB4-4412-B56D-00E8F2796556      None
# 0  5331B126-3AB4-4412-B56D-00E8F2796556      None
# 0  5331B126-3AB4-4412-B56D-00E8F2796556      None
# 0  5331B126-3AB4-4412-B56D-00E8F2796556      None
# 0  5331B126-3AB4-4412-B56D-00E8F2796556      None
#
#                                                 href        created updated  \
# 0  http://gtr.ukri.org/gtr/api/organisations/5331...  1704709432000    None
# 0  http://gtr.ukri.org/gtr/api/organisations/5331...  1704709432000    None
# 0  http://gtr.ukri.org/gtr/api/organisations/5331...  1704709432000    None
# 0  http://gtr.ukri.org/gtr/api/organisations/5331...  1704709432000    None
# 0  http://gtr.ukri.org/gtr/api/organisations/5331...  1704709432000    None
#
#                      name regNumber website  \
# 0  NEWCASTLE CITY COUNCIL      None    None
# 0  NEWCASTLE CITY COUNCIL      None    None
# 0  NEWCASTLE CITY COUNCIL      None    None
# 0  NEWCASTLE CITY COUNCIL      None    None
# 0  NEWCASTLE CITY COUNCIL      None    None
#
#                                            addresses  \
# 0  {'address': [{'links': None, 'ext': None, 'id'...
# 0  {'address': [{'links': None, 'ext': None, 'id'...
# 0  {'address': [{'links': None, 'ext': None, 'id'...
# 0  {'address': [{'links': None, 'ext': None, 'id'...
# 0  {'address': [{'links': None, 'ext': None, 'id'...
#
#                                                 link
# 0  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 0  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 0  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 0  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 0  {'href': 'http://gtr.ukri.org/gtr/api/projects...

# %%
df_id_links = df_exploded[["id", "link", "href"]].copy()
# reset index
df_id_links.reset_index(drop=True, inplace=True)
df_id_links.head()

# remove nans
df_id_links.dropna(inplace=True)
print(len(df_id_links))
# Out:
# 670709

# %%
df_id_links.head()
len(df_id_links)
# Out:
# 670709

# %%
df_id_links = df_exploded[["id", "link", "href"]].copy()
# rename href to href_org
df_id_links.rename(columns={"href": "href_org"}, inplace=True)
print(len(df_id_links))
df_id_links.dropna(inplace=True)
print(len(df_id_links))
normalised = pd.json_normalize(df_id_links["link"])
print(len(normalised))
df_id_links = pd.concat([df_id_links[["id", "href_org"]].reset_index(drop=True), normalised.reset_index(drop=True)], axis=1)
print(len(df_id_links))
# drop columns "index" and "index"
# Out:
# 671161
# 670709
# 670709
# 670709

# %%
# save
df_id_links.to_csv("data/processed/gtr_organisations_links.csv", index=False)

print(df_id_links["href_org"].iloc[0])
# Out:
# http://gtr.ukri.org/gtr/api/organisations/5331B126-3AB4-4412-B56D-00E8F2796556

# %%
df_id_links.head(50)
# Out:
#                                       id  \
# 0   5331B126-3AB4-4412-B56D-00E8F2796556
# 1   5331B126-3AB4-4412-B56D-00E8F2796556
# 2   5331B126-3AB4-4412-B56D-00E8F2796556
# 3   5331B126-3AB4-4412-B56D-00E8F2796556
# 4   5331B126-3AB4-4412-B56D-00E8F2796556
# 5   5331B126-3AB4-4412-B56D-00E8F2796556
# 6   5331B126-3AB4-4412-B56D-00E8F2796556
# 7   5331B126-3AB4-4412-B56D-00E8F2796556
# 8   5331B126-3AB4-4412-B56D-00E8F2796556
# 9   5331B126-3AB4-4412-B56D-00E8F2796556
# 10  5331B126-3AB4-4412-B56D-00E8F2796556
# 11  5331B126-3AB4-4412-B56D-00E8F2796556
# 12  5331B126-3AB4-4412-B56D-00E8F2796556
# 13  5331B126-3AB4-4412-B56D-00E8F2796556
# 14  5331B126-3AB4-4412-B56D-00E8F2796556
# 15  5331B126-3AB4-4412-B56D-00E8F2796556
# 16  5331B126-3AB4-4412-B56D-00E8F2796556
# 17  5331B126-3AB4-4412-B56D-00E8F2796556
# 18  5331B126-3AB4-4412-B56D-00E8F2796556
# 19  5331B126-3AB4-4412-B56D-00E8F2796556
# 20  5331B126-3AB4-4412-B56D-00E8F2796556
# 21  5331B126-3AB4-4412-B56D-00E8F2796556
# 22  5331B126-3AB4-4412-B56D-00E8F2796556
# 23  5331B126-3AB4-4412-B56D-00E8F2796556
# 24  5331B126-3AB4-4412-B56D-00E8F2796556
# 25  5331B126-3AB4-4412-B56D-00E8F2796556
# 26  53331120-0290-49FA-A513-0286A214AF7A
# 27  53331120-0290-49FA-A513-0286A214AF7A
# 28  53331120-0290-49FA-A513-0286A214AF7A
# 29  77874202-2018-4677-8CFF-0868CD838659
# 30  77874202-2018-4677-8CFF-0868CD838659
# 31  77908BF8-1B2D-4D26-9119-155100E8B9C5
# 32  7794C645-9CC7-4913-A8DC-103AE0EFDD4B
# 33  77A41173-DC2B-4D30-A5E2-0B19BE4B8FD5
# 34  77A41173-DC2B-4D30-A5E2-0B19BE4B8FD5
# 35  77A41173-DC2B-4D30-A5E2-0B19BE4B8FD5
# 36  77A41173-DC2B-4D30-A5E2-0B19BE4B8FD5
# 37  77A41173-DC2B-4D30-A5E2-0B19BE4B8FD5
# 38  77A41173-DC2B-4D30-A5E2-0B19BE4B8FD5
# 39  53474E16-DA35-4007-9F07-1B6C0F32BBF6
# 40  5370084A-BDBF-4A7B-8E02-09B7DE95D01B
# 41  5370084A-BDBF-4A7B-8E02-09B7DE95D01B
# 42  5370084A-BDBF-4A7B-8E02-09B7DE95D01B
# 43  53700B68-0910-469D-A0CB-18A3316DF3F2
# 44  53700B68-0910-469D-A0CB-18A3316DF3F2
# 45  537D521C-3D73-458B-A054-196982ADD766
# 46  538761FB-F8B6-4799-9ADA-02F4EF15E8B3
# 47  538761FB-F8B6-4799-9ADA-02F4EF15E8B3
# 48  538761FB-F8B6-4799-9ADA-02F4EF15E8B3
# 49  538761FB-F8B6-4799-9ADA-02F4EF15E8B3
#
#                                              href_org  \
# 0   http://gtr.ukri.org/gtr/api/organisations/5331...
# 1   http://gtr.ukri.org/gtr/api/organisations/5331...
# 2   http://gtr.ukri.org/gtr/api/organisations/5331...
# 3   http://gtr.ukri.org/gtr/api/organisations/5331...
# 4   http://gtr.ukri.org/gtr/api/organisations/5331...
# 5   http://gtr.ukri.org/gtr/api/organisations/5331...
# 6   http://gtr.ukri.org/gtr/api/organisations/5331...
# 7   http://gtr.ukri.org/gtr/api/organisations/5331...
# 8   http://gtr.ukri.org/gtr/api/organisations/5331...
# 9   http://gtr.ukri.org/gtr/api/organisations/5331...
# 10  http://gtr.ukri.org/gtr/api/organisations/5331...
# 11  http://gtr.ukri.org/gtr/api/organisations/5331...
# 12  http://gtr.ukri.org/gtr/api/organisations/5331...
# 13  http://gtr.ukri.org/gtr/api/organisations/5331...
# 14  http://gtr.ukri.org/gtr/api/organisations/5331...
# 15  http://gtr.ukri.org/gtr/api/organisations/5331...
# 16  http://gtr.ukri.org/gtr/api/organisations/5331...
# 17  http://gtr.ukri.org/gtr/api/organisations/5331...
# 18  http://gtr.ukri.org/gtr/api/organisations/5331...
# 19  http://gtr.ukri.org/gtr/api/organisations/5331...
# 20  http://gtr.ukri.org/gtr/api/organisations/5331...
# 21  http://gtr.ukri.org/gtr/api/organisations/5331...
# 22  http://gtr.ukri.org/gtr/api/organisations/5331...
# 23  http://gtr.ukri.org/gtr/api/organisations/5331...
# 24  http://gtr.ukri.org/gtr/api/organisations/5331...
# 25  http://gtr.ukri.org/gtr/api/organisations/5331...
# 26  http://gtr.ukri.org/gtr/api/organisations/5333...
# 27  http://gtr.ukri.org/gtr/api/organisations/5333...
# 28  http://gtr.ukri.org/gtr/api/organisations/5333...
# 29  http://gtr.ukri.org/gtr/api/organisations/7787...
# 30  http://gtr.ukri.org/gtr/api/organisations/7787...
# 31  http://gtr.ukri.org/gtr/api/organisations/7790...
# 32  http://gtr.ukri.org/gtr/api/organisations/7794...
# 33  http://gtr.ukri.org/gtr/api/organisations/77A4...
# 34  http://gtr.ukri.org/gtr/api/organisations/77A4...
# 35  http://gtr.ukri.org/gtr/api/organisations/77A4...
# 36  http://gtr.ukri.org/gtr/api/organisations/77A4...
# 37  http://gtr.ukri.org/gtr/api/organisations/77A4...
# 38  http://gtr.ukri.org/gtr/api/organisations/77A4...
# 39  http://gtr.ukri.org/gtr/api/organisations/5347...
# 40  http://gtr.ukri.org/gtr/api/organisations/5370...
# 41  http://gtr.ukri.org/gtr/api/organisations/5370...
# 42  http://gtr.ukri.org/gtr/api/organisations/5370...
# 43  http://gtr.ukri.org/gtr/api/organisations/5370...
# 44  http://gtr.ukri.org/gtr/api/organisations/5370...
# 45  http://gtr.ukri.org/gtr/api/organisations/537D...
# 46  http://gtr.ukri.org/gtr/api/organisations/5387...
# 47  http://gtr.ukri.org/gtr/api/organisations/5387...
# 48  http://gtr.ukri.org/gtr/api/organisations/5387...
# 49  http://gtr.ukri.org/gtr/api/organisations/5387...
#
#                                                  href       rel start   end
# 0   http://gtr.ukri.org/gtr/api/projects/0D5DF2FF-...   PROJECT  None  None
# 1   http://gtr.ukri.org/gtr/api/projects/0D0F72CC-...   PROJECT  None  None
# 2   http://gtr.ukri.org/gtr/api/projects/0C6849FD-...   PROJECT  None  None
# 3   http://gtr.ukri.org/gtr/api/projects/C4059685-...   PROJECT  None  None
# 4   http://gtr.ukri.org/gtr/api/projects/F0E04953-...   PROJECT  None  None
# 5   http://gtr.ukri.org/gtr/api/projects/D9A401D9-...   PROJECT  None  None
# 6   http://gtr.ukri.org/gtr/api/projects/EC918CE3-...   PROJECT  None  None
# 7   http://gtr.ukri.org/gtr/api/projects/ADB18319-...   PROJECT  None  None
# 8   http://gtr.ukri.org/gtr/api/projects/DCFE5B2E-...   PROJECT  None  None
# 9   http://gtr.ukri.org/gtr/api/projects/1E0BB71C-...   PROJECT  None  None
# 10  http://gtr.ukri.org/gtr/api/projects/2294E699-...   PROJECT  None  None
# 11  http://gtr.ukri.org/gtr/api/projects/A45E2042-...   PROJECT  None  None
# 12  http://gtr.ukri.org/gtr/api/projects/096F035D-...   PROJECT  None  None
# 13  http://gtr.ukri.org/gtr/api/projects/6C78CAA4-...   PROJECT  None  None
# 14  http://gtr.ukri.org/gtr/api/projects/E0B948B2-...   PROJECT  None  None
# 15  http://gtr.ukri.org/gtr/api/projects/1F792DF3-...   PROJECT  None  None
# 16  http://gtr.ukri.org/gtr/api/projects/963F82CE-...   PROJECT  None  None
# 17  http://gtr.ukri.org/gtr/api/projects/A8502FDF-...   PROJECT  None  None
# 18  http://gtr.ukri.org/gtr/api/projects/3AE6C680-...   PROJECT  None  None
# 19  http://gtr.ukri.org/gtr/api/projects/0A2B35E7-...   PROJECT  None  None
# 20  http://gtr.ukri.org/gtr/api/projects/716EFB49-...   PROJECT  None  None
# 21  http://gtr.ukri.org/gtr/api/projects/18B5E7EF-...   PROJECT  None  None
# 22  http://gtr.ukri.org/gtr/api/projects/13A0CD0B-...   PROJECT  None  None
# 23  http://gtr.ukri.org/gtr/api/projects/F41D42DE-...   PROJECT  None  None
# 24  http://gtr.ukri.org/gtr/api/projects/F7EC062A-...   PROJECT  None  None
# 25  http://gtr.ukri.org/gtr/api/persons/0CB4A538-A...  EMPLOYEE  None  None
# 26  http://gtr.ukri.org/gtr/api/projects/B012B0D9-...   PROJECT  None  None
# 27  http://gtr.ukri.org/gtr/api/projects/B0359A89-...   PROJECT  None  None
# 28  http://gtr.ukri.org/gtr/api/persons/951DAD79-1...  EMPLOYEE  None  None
# 29  http://gtr.ukri.org/gtr/api/projects/6272E5E8-...   PROJECT  None  None
# 30  http://gtr.ukri.org/gtr/api/projects/34D4F9E9-...   PROJECT  None  None
# 31  http://gtr.ukri.org/gtr/api/projects/86D3E475-...   PROJECT  None  None
# 32  http://gtr.ukri.org/gtr/api/projects/B6328B17-...   PROJECT  None  None
# 33  http://gtr.ukri.org/gtr/api/projects/7BFFAA57-...   PROJECT  None  None
# 34  http://gtr.ukri.org/gtr/api/projects/261693D8-...   PROJECT  None  None
# 35  http://gtr.ukri.org/gtr/api/projects/A5C71609-...   PROJECT  None  None
# 36  http://gtr.ukri.org/gtr/api/projects/024FE285-...   PROJECT  None  None
# 37  http://gtr.ukri.org/gtr/api/projects/19B1184B-...   PROJECT  None  None
# 38  http://gtr.ukri.org/gtr/api/projects/2316473B-...   PROJECT  None  None
# 39  http://gtr.ukri.org/gtr/api/projects/A1026C17-...   PROJECT  None  None
# 40  http://gtr.ukri.org/gtr/api/projects/DDBC1424-...   PROJECT  None  None
# 41  http://gtr.ukri.org/gtr/api/projects/248C1BF6-...   PROJECT  None  None
# 42  http://gtr.ukri.org/gtr/api/persons/77F68725-5...  EMPLOYEE  None  None
# 43  http://gtr.ukri.org/gtr/api/projects/DD73BF27-...   PROJECT  None  None
# 44  http://gtr.ukri.org/gtr/api/projects/96E64EB6-...   PROJECT  None  None
# 45  http://gtr.ukri.org/gtr/api/projects/C34CB6BB-...   PROJECT  None  None
# 46  http://gtr.ukri.org/gtr/api/projects/BA986004-...   PROJECT  None  None
# 47  http://gtr.ukri.org/gtr/api/projects/984AC337-...   PROJECT  None  None
# 48  http://gtr.ukri.org/gtr/api/projects/99E40BE4-...   PROJECT  None  None
# 49  http://gtr.ukri.org/gtr/api/projects/BC739729-...   PROJECT  None  None

# %% [markdown]
# # On GTR...
# Each Organisation href links to a list of associated projects and employees.
# * https://gtr.ukri.org/gtr/api/organisations/5331B126-3AB4-4412-B56D-00E8F2796556
#
# * Links to EMPLOYEE (e.g. https://gtr.ukri.org/gtr/api/persons/0CB4A538-AC14-4394-A10F-C9F955033EF3) give first name and last name.
# * Links to PROJECT give a lot of fields including "RESEARCH_PER" which gives the person associated with the project.
#   * Several fields ending with PER for people associated
#   * Several fields ending with ORG for organisations associated
# * COLLABORATION field is an outcome thatcontains further related organisation information.
# * PARTICIPATION doesn't seem to have much
# * FURTHER FUNDING lists the sector of the orgnaisation, could be useful
# * PUBLICATION field is useful - contains link to publication URL that can be used to match additional fields (organisation and authors), doi, and author name.
#   * https://gtr.ukri.org/gtr/api/outcomes/publications/0B3A64BD-9D0B-42DC-96EC-4BA34632C9C7
#   *
#
# Projects have three additional sections
# * Organisations
# * People
#
# Employee

# %%
# convert to nested dictionary
# {id: rows from link with the same id}
id_links = df_id_links.groupby("id") # .apply(lambda x: x.to_dict(orient='records')).to_dict()
id_links.head()
# Out:
#                                           id  \
# 0       5331B126-3AB4-4412-B56D-00E8F2796556
# 1       5331B126-3AB4-4412-B56D-00E8F2796556
# 2       5331B126-3AB4-4412-B56D-00E8F2796556
# 3       5331B126-3AB4-4412-B56D-00E8F2796556
# 4       5331B126-3AB4-4412-B56D-00E8F2796556
# ...                                      ...
# 670581  DEAD23AB-66BF-4D61-BC10-2CC8BF055693
# 670582  DEAD23AB-66BF-4D61-BC10-2CC8BF055693
# 670583  DEAD23AB-66BF-4D61-BC10-2CC8BF055693
# 670707  0D4FDCE2-32C8-4FC1-A582-331BEE2B5C1F
# 670708  E15F7794-DE6A-4BF3-814D-075FDAE2E332
#
#                                                  href_org  \
# 0       http://gtr.ukri.org/gtr/api/organisations/5331...
# 1       http://gtr.ukri.org/gtr/api/organisations/5331...
# 2       http://gtr.ukri.org/gtr/api/organisations/5331...
# 3       http://gtr.ukri.org/gtr/api/organisations/5331...
# 4       http://gtr.ukri.org/gtr/api/organisations/5331...
# ...                                                   ...
# 670581  http://gtr.ukri.org/gtr/api/organisations/DEAD...
# 670582  http://gtr.ukri.org/gtr/api/organisations/DEAD...
# 670583  http://gtr.ukri.org/gtr/api/organisations/DEAD...
# 670707  http://gtr.ukri.org/gtr/api/organisations/0D4F...
# 670708  http://gtr.ukri.org/gtr/api/organisations/E15F...
#
#                                                      href       rel start  \
# 0       http://gtr.ukri.org/gtr/api/projects/0D5DF2FF-...   PROJECT  None
# 1       http://gtr.ukri.org/gtr/api/projects/0D0F72CC-...   PROJECT  None
# 2       http://gtr.ukri.org/gtr/api/projects/0C6849FD-...   PROJECT  None
# 3       http://gtr.ukri.org/gtr/api/projects/C4059685-...   PROJECT  None
# 4       http://gtr.ukri.org/gtr/api/projects/F0E04953-...   PROJECT  None
# ...                                                   ...       ...   ...
# 670581  http://gtr.ukri.org/gtr/api/projects/EE39AFFE-...   PROJECT  None
# 670582  http://gtr.ukri.org/gtr/api/projects/1717F5F9-...   PROJECT  None
# 670583  http://gtr.ukri.org/gtr/api/projects/E6A07D25-...   PROJECT  None
# 670707  http://gtr.ukri.org/gtr/api/projects/8D402FF2-...   PROJECT  None
# 670708  http://gtr.ukri.org/gtr/api/persons/E64F80AA-6...  EMPLOYEE  None
#
#          end
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# ...      ...
# 670581  None
# 670582  None
# 670583  None
# 670707  None
# 670708  None
#
# [150365 rows x 6 columns]

# %%
# lets just look at the link column for now by converting to list
link_list = df_exploded["link"].to_list()
for link_dict in link_list[:5]:
    pprint(link_dict)
# Out:
# {'end': None,
#  'href': 'http://gtr.ukri.org/gtr/api/projects/0D5DF2FF-B732-4218-B0E3-4FFBF3DDC906',
#  'otherAttributes': {},
#  'rel': 'PROJECT',
#  'start': None}
# {'end': None,
#  'href': 'http://gtr.ukri.org/gtr/api/projects/0D0F72CC-0163-47CE-A462-5FDDBA4C1C38',
#  'otherAttributes': {},
#  'rel': 'PROJECT',
#  'start': None}
# {'end': None,
#  'href': 'http://gtr.ukri.org/gtr/api/projects/0C6849FD-CA2D-49A9-80D4-75F710980208',
#  'otherAttributes': {},
#  'rel': 'PROJECT',
#  'start': None}
# {'end': None,
#  'href': 'http://gtr.ukri.org/gtr/api/projects/C4059685-9263-44E6-B89A-D8609FCC1360',
#  'otherAttributes': {},
#  'rel': 'PROJECT',
#  'start': None}
# {'end': None,
#  'href': 'http://gtr.ukri.org/gtr/api/projects/F0E04953-58F2-46FB-9837-3C341A3D3165',
#  'otherAttributes': {},
#  'rel': 'PROJECT',
#  'start': None}

# %%
# remove nans from link_list
link_list = [x for x in link_list if type(x) == dict]
types_bool = [x for x in link_list if not type(x) == dict]
print(types_bool)
# Out:
# []

# %%
#

# %%
df_from_list = pd.DataFrame(link_list)
df_from_list.head()sa
# Out:
#   Cell In[21], line 2
#     df_from_list.head()sa
#                        ^
# SyntaxError: invalid syntax

# %%
print(df_from_list["rel"].unique())
# Out:
# ['PROJECT' 'EMPLOYEE']

# %%
from collections import defaultdict

def find_unique_values(list_of_dicts):    
    for d in list_of_dicts:
        for key, value in d.items():
            result[key].add(value)
    # Convert sets to lists for the final output
    return {k: list(v) for k, v in result.items()}

unique_values = find_unique_values(link_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[131], line 12
#       9     # Convert sets to lists for the final output
#      10     return {k: list(v) for k, v in result.items()}
# ---> 12 unique_values = find_unique_values(link_list)
#
# Cell In[131], line 8, in find_unique_values(list_of_dicts)
#       6 for d in list_of_dicts:
#       7     for key, value in d.items():
# ----> 8         result[key].add(value)
#       9 # Convert sets to lists for the final output
#      10 return {k: list(v) for k, v in result.items()}
#
# AttributeError: 'list' object has no attribute 'add'

# %%
df_exploded.head()
print(df_exploded["link"].iloc[0])
print(df_exploded["link"].iloc[1])
print(df_exploded["link"].iloc[2])
print(df_exploded["link"].iloc[3])
print(df_exploded["link"].iloc[4])
print(df_exploded["link"].iloc[5])
print(df_exploded["link"].iloc[6])
print(df_exploded["link"].iloc[7])
print(df_exploded["link"].iloc[8])
print(df_exploded["link"].iloc[9])
print(df_exploded["link"].iloc[10])
print(df_exploded["link"].iloc[11])
print(df_exploded["link"].iloc[12])
print(df_exploded["link"].iloc[13])
print(df_exploded["link"].iloc[14])
print(df_exploded["link"].iloc[15])
print(df_exploded["link"].iloc[16])
print(df_exploded["link"].iloc[17])
print(df_exploded["link"].iloc[18])
print(df_exploded["link"].iloc[19])
print(df_exploded["link"].iloc[20])
print(df_exploded["link"].iloc[21])
print(df_exploded["link"].iloc[22])
print(df_exploded["link"].iloc[23])
print(df_exploded["link"].iloc[24])
print(df_exploded["link"].iloc[25])
print(df_exploded["link"].iloc[26])
# Out:
# {'href': 'http://gtr.ukri.org/gtr/api/projects/0D5DF2FF-B732-4218-B0E3-4FFBF3DDC906', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/0D0F72CC-0163-47CE-A462-5FDDBA4C1C38', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/0C6849FD-CA2D-49A9-80D4-75F710980208', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/C4059685-9263-44E6-B89A-D8609FCC1360', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/F0E04953-58F2-46FB-9837-3C341A3D3165', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/D9A401D9-6D91-4DA6-9012-7137774B1DD8', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/EC918CE3-4862-4EED-884A-E1AC42C8F46D', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/ADB18319-E0B8-4735-AC8B-59946A4BB9CB', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/DCFE5B2E-2EC2-4AA2-9244-EE252CED60E4', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/1E0BB71C-795B-4D20-B46C-2E618CAC96C0', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/2294E699-BBAC-47CB-9293-6BAC6BED2640', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/A45E2042-8FFF-40EF-B270-15D95481946E', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/096F035D-FAEB-4187-9C63-1DA5337E85B9', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/6C78CAA4-62B1-40BC-AF39-A2949521BEB9', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/E0B948B2-4771-4063-BCF0-2E0B58080049', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/1F792DF3-9B47-41E9-96E6-9F90F754314B', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/963F82CE-27D8-460F-9DB3-D61E8D7380AA', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/A8502FDF-589C-4C08-861E-895C6D1BB126', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/3AE6C680-4967-4B0E-94FF-E1DA2DF79838', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/0A2B35E7-1DCC-48D3-A6BC-14A8C4C4FCA0', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/716EFB49-3F49-4618-850E-2BC9E83679DC', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/18B5E7EF-CF71-4F59-87BB-E7F6DEE92508', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/13A0CD0B-7912-484E-BE83-7A82F703533F', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/F41D42DE-E390-4DA4-BE95-FBBBDB61CBC0', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/F7EC062A-3B31-4C42-9E03-CA013F58242B', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/persons/0CB4A538-AC14-4394-A10F-C9F955033EF3', 'rel': 'EMPLOYEE', 'start': None, 'end': None, 'otherAttributes': {}}
# {'href': 'http://gtr.ukri.org/gtr/api/projects/B012B0D9-EEBC-414F-BA4A-8AF2B1898477', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}

# %%
# finally, as before, blow up the link column
# def expand_link_column_dicts(df):
#     """
#     Only works for address column
#     """
#     df_level_one = expand_dictionary_column(df, "addresses")
#     new_col_names = [col for col in df_level_one.columns.to_list() if col not in original_df.columns.to_list()]
#     print(new_col_names)
#     df_level_one.head()
#     return map_each_dict_in_list_to_new_column(df_level_one, new_col_names)

df_links = expand_dictionary_column(df, "link")
df_links.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[110], line 12
#       1 # finally, as before, blow up the link column
#       2 # def expand_link_column_dicts(df):
#       3 #     """
#    (...)
#       9 #     df_level_one.head()
#      10 #     return map_each_dict_in_list_to_new_column(df_level_one, new_col_names)
# ---> 12 df_links = expand_dictionary_column(df, "link")
#      13 df_links.head()
#
# Cell In[92], line 8, in expand_dictionary_column(df, column_name)
#       5 # get new columns from dictionary
#       6 new_columns = pd.json_normalize(original_column)
# ----> 8 df_level_one = pd.concat([new_columns, original_column], axis=1)
#       9 return df_level_one
#
# File c:\Users\dec2g\anaconda3\envs\dan-env\lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File c:\Users\dec2g\anaconda3\envs\dan-env\lib\site-packages\pandas\core\reshape\concat.py:433, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     428 else:  # pragma: no cover
#     429     raise ValueError(
#     430         "Only can inner (intersect) or outer (union) join the other axis"
#     431     )
# --> 433 if not is_bool(sort):
#     434     raise ValueError(
#     435         f"The 'sort' keyword only accepts boolean values; {sort} was passed."
#     436     )
#     437 # Incompatible types in assignment (expression has type "Union[bool, bool_]",
#     438 # variable has type "bool")
#
# KeyboardInterrupt:

# %%
# Step 2: (for creating rows) create new columns for each dictionary in the list of dictionaries
# collect each dictionary column in the list of dictionaries
exploded_dfs = []

# go through each new column in level one
for col in new_col_names:
    if type(df_level_one[col].iloc[0]) == list:
        # Step 2: explode the list of dictionaries into separate rows
        explode = df_level_one.copy().explode(col)[col]
        # Step 3
        exploded_dfs.append(explode)


# pprint first element
# pprint(exploded_dfs[0].iloc[0])
# for exploded_in_e
# new_columns = pd.concat(exploded_dfs, axis=1)
# new_columns.head()
        # new_columns = pd.json_normalize(df_normalised[col])
# Out:
# 0    {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 0    {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 0    {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 0    {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 0    {'href': 'http://gtr.ukri.org/gtr/api/projects...
# Name: link, dtype: object

# %%
def explode_iteratively(df, column_name):
    series = df[column_name]

    def get_series_type(series):
        column_values_type = series.apply(lambda x: type(x)).unique()
        if len(column_values_type) > 1:
            print(f"Column {column_name} contains multiple types: {column_values_type}")
            return None
        else:
            return column_values_type[0]
        
    series_type = get_series_type(series)

    if series_type == dict:
# Out:
#   Cell In[4], line 15
#
#     ^
# SyntaxError: incomplete input

# %%
df_dicts = df[["addresses"]].copy()
series = df_dicts["addresses"]
# print type of all values in the column if all same
print(series.apply(lambda x: type(x)).unique())
df_dict = df.copy()
for key in series[0].keys():
    df_dicts[key] = series.apply(lambda x: x.get(key))
df_dicts.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = json_to_df("data/orgsync.json")
#       2 df_dicts = df[["addresses"]].copy()
#       3 series = df_dicts["addresses"]
#
# Cell In[7], line 2, in json_to_df(path)
#       1 def json_to_df(path:str):
# ----> 2     with open(path, 'r') as f:
#       3         data = json.load(f)
#       4     return pd.DataFrame(data)
#
# File c:\Users\dec2g\anaconda3\envs\dan-env\lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/orgsync.json'

# %%
column_name = "addresses"
df_dicts = df[[column_name]].copy()
df_dicts.head()
df_normalised = pd.concat([pd.json_normalize(df_dicts[column_name]), df_dicts], axis=1)
df_normalised.head()

drop_names = [column_name]

column_name = df_normalised.columns.to_list()[0]
df_exploded = df_normalised.explode(column_name)
df_exploded.head()

drop_names.append(column_name)

df_normalised = pd.concat([pd.json_normalize(df_exploded[column_name]), df_exploded], axis=1)
df_normalised.head()

# drop all drop names
df_normalised.drop(drop_names, axis=1, inplace=True)
df_normalised.head()
# Out:
#    links  ext                                    id  outcomeid  href  \
# 0    NaN  NaN  C20B6399-DBC6-4523-9C69-946A304A37D7        NaN   NaN
# 1    NaN  NaN  AF7F7686-3DE3-475B-BCED-201E39037299        NaN   NaN
# 2    NaN  NaN                                   NaN        NaN   NaN
# 3    NaN  NaN  51E6A87A-834A-4596-9054-C2D76E37A389        NaN   NaN
# 4    NaN  NaN  61C06F28-0616-4787-8974-781CD5997724        NaN   NaN
#
#         created  updated  line1  line2  line3  line4  line5  city  county  \
# 0  1.720391e+12      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN
# 1  1.720391e+12      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN
# 2           NaN      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN
# 3  1.720391e+12      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN
# 4  1.720391e+12      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN
#
#    postCode           region  country          type
# 0   NE1 8QH       North East      NaN  MAIN_ADDRESS
# 1  MK14 6GD       South East      NaN  MAIN_ADDRESS
# 2       NaN              NaN      NaN           NaN
# 3  PE29 6FN  East of England      NaN  MAIN_ADDRESS
# 4     20814          Unknown      NaN  MAIN_ADDRESS

# %%
df_exploded = df_dicts.explode("address")
# df_normalised = pd.json_normalize(df_exploded["addresses"])
# df_normalised.head()
df_exploded.head()

# # if still list of dictionaries, explode again
# df_exploded = df_exploded.explode("address")
# # 
# df_exploded.head()
# Out:
#                                            addresses  \
# 0  {'address': [{'links': None, 'ext': None, 'id'...
# 1  {'address': [{'links': None, 'ext': None, 'id'...
# 2                                    {'address': []}
# 3  {'address': [{'links': None, 'ext': None, 'id'...
# 4  {'address': [{'links': None, 'ext': None, 'id'...
#
#                                              address
# 0  {'links': None, 'ext': None, 'id': 'C20B6399-D...
# 1  {'links': None, 'ext': None, 'id': 'AF7F7686-3...
# 2                                                NaN
# 3  {'links': None, 'ext': None, 'id': '51E6A87A-8...
# 4  {'links': None, 'ext': None, 'id': '61C06F28-0...

# %%
df_normalised = pd.json_normalize(df_exploded["address"])
df_normalised.head()
# Out:
#    links  ext                                    id  outcomeid  href  \
# 0    NaN  NaN  C20B6399-DBC6-4523-9C69-946A304A37D7        NaN   NaN
# 1    NaN  NaN  AF7F7686-3DE3-475B-BCED-201E39037299        NaN   NaN
# 2    NaN  NaN                                   NaN        NaN   NaN
# 3    NaN  NaN  51E6A87A-834A-4596-9054-C2D76E37A389        NaN   NaN
# 4    NaN  NaN  61C06F28-0616-4787-8974-781CD5997724        NaN   NaN
#
#         created  updated  line1  line2  line3  line4  line5  city  county  \
# 0  1.720391e+12      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN
# 1  1.720391e+12      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN
# 2           NaN      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN
# 3  1.720391e+12      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN
# 4  1.720391e+12      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN
#
#    postCode           region  country          type
# 0   NE1 8QH       North East      NaN  MAIN_ADDRESS
# 1  MK14 6GD       South East      NaN  MAIN_ADDRESS
# 2       NaN              NaN      NaN           NaN
# 3  PE29 6FN  East of England      NaN  MAIN_ADDRESS
# 4     20814          Unknown      NaN  MAIN_ADDRESS

# %%
print(df_dicts["address"].apply(lambda x: type(x)).unique())
print(all(df_dicts["address"].apply(lambda x: all([type(y) == dict for y in x])).to_list()))
df_lists = df_dicts.explode("address")
df_normalized = pd.json_normalize(df_lists["address"])
# df_lists.head()
df_normalized.head()
# Out:
# [<class 'list'>]
# True
#    links  ext                                    id  outcomeid  href  \
# 0    NaN  NaN  C20B6399-DBC6-4523-9C69-946A304A37D7        NaN   NaN
# 1    NaN  NaN  AF7F7686-3DE3-475B-BCED-201E39037299        NaN   NaN
# 2    NaN  NaN                                   NaN        NaN   NaN
# 3    NaN  NaN  51E6A87A-834A-4596-9054-C2D76E37A389        NaN   NaN
# 4    NaN  NaN  61C06F28-0616-4787-8974-781CD5997724        NaN   NaN
#
#         created  updated  line1  line2  line3  line4  line5  city  county  \
# 0  1.720391e+12      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN
# 1  1.720391e+12      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN
# 2           NaN      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN
# 3  1.720391e+12      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN
# 4  1.720391e+12      NaN    NaN    NaN    NaN    NaN    NaN   NaN     NaN
#
#    postCode           region  country          type
# 0   NE1 8QH       North East      NaN  MAIN_ADDRESS
# 1  MK14 6GD       South East      NaN  MAIN_ADDRESS
# 2       NaN              NaN      NaN           NaN
# 3  PE29 6FN  East of England      NaN  MAIN_ADDRESS
# 4     20814          Unknown      NaN  MAIN_ADDRESS

# %% [markdown]
# There are two files containing the GtR data but currently these are identical, so we just need to load one of them.
# * `data/raw/all_scraped/gtr/scraped/2024_07/organisations.json`
# * `data/raw/all_scraped/gtr/scraped/2024_07/organisations_2.json`

# %%
print(df_dicts["links"][0])
# Out:
# {'link': [{'href': 'http://gtr.ukri.org/gtr/api/projects/0D5DF2FF-B732-4218-B0E3-4FFBF3DDC906', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/0D0F72CC-0163-47CE-A462-5FDDBA4C1C38', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/0C6849FD-CA2D-49A9-80D4-75F710980208', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/C4059685-9263-44E6-B89A-D8609FCC1360', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/F0E04953-58F2-46FB-9837-3C341A3D3165', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/D9A401D9-6D91-4DA6-9012-7137774B1DD8', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/EC918CE3-4862-4EED-884A-E1AC42C8F46D', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/ADB18319-E0B8-4735-AC8B-59946A4BB9CB', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/DCFE5B2E-2EC2-4AA2-9244-EE252CED60E4', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/1E0BB71C-795B-4D20-B46C-2E618CAC96C0', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/2294E699-BBAC-47CB-9293-6BAC6BED2640', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/A45E2042-8FFF-40EF-B270-15D95481946E', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/096F035D-FAEB-4187-9C63-1DA5337E85B9', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/6C78CAA4-62B1-40BC-AF39-A2949521BEB9', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/E0B948B2-4771-4063-BCF0-2E0B58080049', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/1F792DF3-9B47-41E9-96E6-9F90F754314B', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/963F82CE-27D8-460F-9DB3-D61E8D7380AA', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/A8502FDF-589C-4C08-861E-895C6D1BB126', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/3AE6C680-4967-4B0E-94FF-E1DA2DF79838', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/0A2B35E7-1DCC-48D3-A6BC-14A8C4C4FCA0', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/716EFB49-3F49-4618-850E-2BC9E83679DC', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/18B5E7EF-CF71-4F59-87BB-E7F6DEE92508', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/13A0CD0B-7912-484E-BE83-7A82F703533F', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/F41D42DE-E390-4DA4-BE95-FBBBDB61CBC0', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/projects/F7EC062A-3B31-4C42-9E03-CA013F58242B', 'rel': 'PROJECT', 'start': None, 'end': None, 'otherAttributes': {}}, {'href': 'http://gtr.ukri.org/gtr/api/persons/0CB4A538-AC14-4394-A10F-C9F955033EF3', 'rel' ...

# %%
df_ = expand_columns_containing_dictionaries(df_dicts, "links")
df_.head()
# Out:
#     ext                                    id outcomeid  \
# 0  None  5331B126-3AB4-4412-B56D-00E8F2796556      None
# 1  None  53331120-0290-49FA-A513-0286A214AF7A      None
# 2  None  77874202-2018-4677-8CFF-0868CD838659      None
# 3  None  77908BF8-1B2D-4D26-9119-155100E8B9C5      None
# 4  None  7794C645-9CC7-4913-A8DC-103AE0EFDD4B      None
#
#                                                 href        created updated  \
# 0  http://gtr.ukri.org/gtr/api/organisations/5331...  1704709432000    None
# 1  http://gtr.ukri.org/gtr/api/organisations/5333...  1704709432000    None
# 2  http://gtr.ukri.org/gtr/api/organisations/7787...  1704709432000    None
# 3  http://gtr.ukri.org/gtr/api/organisations/7790...  1704709432000    None
# 4  http://gtr.ukri.org/gtr/api/organisations/7794...  1704709432000    None
#
#                                    name regNumber website  \
# 0                NEWCASTLE CITY COUNCIL      None    None
# 1                   VALERANN UK LIMITED      None    None
# 2  Baltic Sea Cultural Centre in Gdansk      None    None
# 3                               Mindray      None    None
# 4               Democracy International      None    None
#
#                                            addresses  links_0
# 0  {'address': [{'links': None, 'ext': None, 'id'...      NaN
# 1  {'address': [{'links': None, 'ext': None, 'id'...      NaN
# 2                                    {'address': []}      NaN
# 3  {'address': [{'links': None, 'ext': None, 'id'...      NaN
# 4  {'address': [{'links': None, 'ext': None, 'id'...      NaN

# %% [markdown]
# The dataset has the following fields:
# * links
# * ext
# * id
# * outcomeid
# * href
# * created
# * updated
# * name
# * regNumber
# * website
# * addresses
#
# `links` and `addresses` are nested dictionaries and need to be expanded.

# %% [markdown]
# Some columns have the same value across all rows. These columns are not useful for analysis.
#
# Remove all columns where each row contains the same value.

# %%
check_columns_are_unique(df_dicts)
df_ = remove_columns_with_single_unique_value(df_dicts)
df_.head()
# Out:
# links  unhashable type: object
# ext  has unique values: False
# id  has unique values: True
# outcomeid  has unique values: False
# href  has unique values: True
# created  has unique values: True
# updated  has unique values: False
# name  has unique values: True
# regNumber  has unique values: False
# website  has unique values: False
# addresses  unhashable type: object
#                                                links  \
# 0  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
# 1  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
# 2  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
# 3  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
# 4  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
#
#                                      id  \
# 0  5331B126-3AB4-4412-B56D-00E8F2796556
# 1  53331120-0290-49FA-A513-0286A214AF7A
# 2  77874202-2018-4677-8CFF-0868CD838659
# 3  77908BF8-1B2D-4D26-9119-155100E8B9C5
# 4  7794C645-9CC7-4913-A8DC-103AE0EFDD4B
#
#                                                 href        created  \
# 0  http://gtr.ukri.org/gtr/api/organisations/5331...  1704709432000
# 1  http://gtr.ukri.org/gtr/api/organisations/5333...  1704709432000
# 2  http://gtr.ukri.org/gtr/api/organisations/7787...  1704709432000
# 3  http://gtr.ukri.org/gtr/api/organisations/7790...  1704709432000
# 4  http://gtr.ukri.org/gtr/api/organisations/7794...  1704709432000
#
#                                    name  \
# 0                NEWCASTLE CITY COUNCIL
# 1                   VALERANN UK LIMITED
# 2  Baltic Sea Cultural Centre in Gdansk
# 3                               Mindray
# 4               Democracy International
#
#                                            addresses
# 0  {'address': [{'links': None, 'ext': None, 'id'...
# 1  {'address': [{'links': None, 'ext': None, 'id'...
# 2                                    {'address': []}
# 3  {'address': [{'links': None, 'ext': None, 'id'...
# 4  {'address': [{'links': None, 'ext': None, 'id'...
