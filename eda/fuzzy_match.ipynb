# %%
import json
import pandas as pd
from fuzzywuzzy import fuzz, process
from collections import defaultdict

# Load the UK names data
with open('../data/raw/uk_data.json', 'r') as file:
    uk_data = json.load(file)

# Extract unique names
uk_names = list(set(entry['name'] for entry in uk_data))

# Function to group similar names using fuzzy matching
def group_similar_names(names, threshold=80):
    grouped_names = defaultdict(list)
    used_names = set()

    for name in names:
        if name in used_names:
            continue

        # Find the best matches for the current name
        matches = process.extract(name, names, scorer=fuzz.token_sort_ratio)

        # Filter matches that meet the threshold
        similar_names = [match[0] for match in matches if match[1] >= threshold and match[0] != name]

        # Add the name and its matches to the grouped names
        grouped_names[name].extend(similar_names)
        
        # Mark these names as used
        used_names.add(name)
        used_names.update(similar_names)

    return grouped_names

# Group the UK names
threshold = 80  # Adjust the threshold as needed
grouped_names = group_similar_names(uk_names, threshold=threshold)

# Convert the grouped names into a DataFrame for easier viewing
grouped_names_df = pd.DataFrame({
    'Name': grouped_names.keys(),
    'Similar Names': ['; '.join(names) for names in grouped_names.values()]
})

# Display the first few groups
grouped_names_df.head(20)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import json
#       2 import pandas as pd
# ----> 3 from fuzzywuzzy import fuzz, process
#       4 from collections import defaultdict
#       6 # Load the UK names data
#
# ModuleNotFoundError: No module named 'fuzzywuzzy'

# %%
import json
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
from collections import defaultdict

# Load the UK names data
with open('../data/raw/uk_data.json', 'r') as file:
    uk_data = json.load(file)

# Extract unique names
uk_names = list(set(entry['name'] for entry in uk_data))

# Vectorize the names using TF-IDF
vectorizer = TfidfVectorizer().fit(uk_names)
name_vectors = vectorizer.transform(uk_names)

# Use Nearest Neighbors to find similar names
nbrs = NearestNeighbors(n_neighbors=10, metric='cosine', algorithm='brute').fit(name_vectors)
distances, indices = nbrs.kneighbors(name_vectors)

# Group similar names
threshold = 0.9  # Cosine similarity threshold (0 to 1, lower means more similar)
grouped_names = defaultdict(list)
used_names = set()

for i, name in enumerate(uk_names):
    if name in used_names:
        continue

    # Get similar names based on the cosine similarity
    similar_names = [uk_names[idx] for j, idx in enumerate(indices[i]) if distances[i][j] <= threshold and idx != i]
    
    if similar_names:  # Only consider if there are matches
        # Add to the group and mark as used
        grouped_names[name].extend(similar_names)
        used_names.add(name)
        used_names.update(similar_names)

# Convert the grouped names into a DataFrame for easier viewing
grouped_names_df = pd.DataFrame({
    'Name': grouped_names.keys(),
    'Similar Names': ['; '.join(names) for names in grouped_names.values()]
})

# Filter to show only items with matches
grouped_names_df = grouped_names_df[grouped_names_df['Similar Names'].str.len() > 0]

# Output statistics
total_unique_names = len(uk_names)
total_matched_names = len(grouped_names_df)
total_matches = grouped_names_df['Similar Names'].apply(lambda x: len(x.split('; '))).sum()

print(f"Total unique UK names: {total_unique_names}")
print(f"Total unique names with matches: {total_matched_names}")
print(f"Total number of matches found: {total_matches}")
print(f"Percentage of unique names with matches: {total_matched_names / total_unique_names * 100:.2f}%")

# Display the first few groups with matches
grouped_names_df.head(20)
# Out:
# Total unique UK names: 5422
# Total unique names with matches: 2684
# Total number of matches found: 14620
# Percentage of unique names with matches: 49.50%
#                                                Name  \
# 0                CHAS A BLATCHFORD AND SONS LIMITED
# 1                              LIMITEDSKIES LIMITED
# 2                                     PIXELMILL LTD
# 3                                       BFM LIMITED
# 4                    DESAP SYSTEM SOLUTIONS LIMITED
# 5                               REPORTBRAIN LIMITED
# 6                                      MAIER UK LTD
# 7                                       Nile HQ Ltd
# 8                                  CLOUDWEAVERS LTD
# 9                             ICONAL TECHNOLOGY LTD
# 10            THE ASSOCIATION FOR SCIENCE EDUCATION
# 11                            ColdQuanta UK Limited
# 12               WAIDE STRATEGIC EFFICIENCY LIMITED
# 13                                     MIDATECH LTD
# 14  POLICE AND CRIME COMMISSIONER FOR THAMES VALLEY
# 15                BOD AYRE SEAWEED PRODUCTS LIMITED
# 16                          PLF AGRITECH EUROPE LTD
# 17                                 MEDIBIOSENSE LTD
# 18                                         AQIX LTD
# 19                                 POLYFLOR LIMITED
#
#                                         Similar Names
# 0   G R WRIGHT AND SONS LTD; John Wiley and Sons L...
# 1                I.C.T.S.(U.K.) LIMITED; C.D. LIMITED
# 2    T.L.R. LTD; B G RESEARCH LTD; Q TECHNOLOGIES LTD
# 3                I.C.T.S.(U.K.) LIMITED; C.D. LIMITED
# 4   X-SYSTEM; DESAP ENTERPRISES LIMITED; INTEGRATE...
# 5                I.C.T.S.(U.K.) LIMITED; C.D. LIMITED
# 6   O.S. Energy (UK) Ltd; T.L.R. LTD; DAIRY UK LTD...
# 7                                          T.L.R. LTD
# 8    T.L.R. LTD; B G RESEARCH LTD; Q TECHNOLOGIES LTD
# 9   INTEGRATION TECHNOLOGY LTD; MICROWAVE TECHNOLO...
# 10  BRITISH ASSOCIATION FOR THE ADVANCEMENT OF SCI...
# 11  S&P GLOBAL UK LIMITED; B/E AEROSPACE (UK) LIMI...
# 12  STRATEGIC BLUE SERVICES LIMITED; STRATEGIC SOC...
# 13   T.L.R. LTD; B G RESEARCH LTD; Q TECHNOLOGIES LTD
# 14  POLICE AND CRIME COMMISSIONER FOR WEST YORKSHI...
# 15  HEBRIDEAN SEAWEED COMPANY LIMITED; COAL PRODUC...
# 16  DEVELOPMENT SOLUTIONS EUROPE LTD; IQE (EUROPE)...
# 17   T.L.R. LTD; B G RESEARCH LTD; Q TECHNOLOGIES LTD
# 18   T.L.R. LTD; B G RESEARCH LTD; Q TECHNOLOGIES LTD
# 19               I.C.T.S.(U.K.) LIMITED; C.D. LIMITED

# %%
# save the df to tmp/uk_names_grouped.csv
# grouped_names_df.to_csv('tmp/uk_names_grouped.csv', index=False)

# %%
import json
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
from collections import defaultdict

# Load the UK names data
with open('../data/raw/uk_data.json', 'r') as file:
    uk_data = json.load(file)

# Combine the name, short_name, and standardized_name fields
def combine_names(entry):
    return ' '.join(filter(None, [entry.get('name', ''), entry.get('short_name', ''), entry.get('standardized_name', '')]))

# Create a list of combined names
combined_names = [combine_names(entry) for entry in uk_data]

# Remove exact duplicates to keep only unique combined names
unique_combined_names = list(set(combined_names))

# Vectorize the unique combined names using TF-IDF
vectorizer = TfidfVectorizer().fit(unique_combined_names)
name_vectors = vectorizer.transform(unique_combined_names)

# Use Nearest Neighbors to find similar names
nbrs = NearestNeighbors(n_neighbors=10, metric='cosine', algorithm='brute').fit(name_vectors)
distances, indices = nbrs.kneighbors(name_vectors)

# Group similar names
threshold = 0.2  # Cosine similarity threshold (0 to 1, lower means more similar)
grouped_names = defaultdict(list)
used_names = set()

for i, name in enumerate(unique_combined_names):
    if name in used_names:
        continue

    # Get similar names based on the cosine similarity
    similar_names = [unique_combined_names[idx] for j, idx in enumerate(indices[i]) if distances[i][j] <= threshold and idx != i]
    
    if similar_names:  # Only consider if there are matches
        # Add to the group and mark as used
        grouped_names[name].extend(similar_names)
        used_names.add(name)
        used_names.update(similar_names)

# Convert the grouped names into a DataFrame for easier viewing
grouped_names_df = pd.DataFrame({
    'Name': grouped_names.keys(),
    'Similar Names': ['; '.join(names) for names in grouped_names.values()]
})

# Filter to show only items with matches
grouped_names_df = grouped_names_df[grouped_names_df['Similar Names'].str.len() > 0]

# Output statistics
total_unique_names = len(unique_combined_names)
total_matched_names = len(grouped_names_df)
total_matches = grouped_names_df['Similar Names'].apply(lambda x: len(x.split('; '))).sum()

print(f"Total unique combined names: {total_unique_names}")
print(f"Total unique combined names with matches: {total_matched_names}")
print(f"Total number of matches found: {total_matches}")
print(f"Percentage of unique combined names with matches: {total_matched_names / total_unique_names * 100:.2f}%")

# Display the first few groups with matches
grouped_names_df.head(20)
# Out:
# Total unique combined names: 5422
# Total unique combined names with matches: 61
# Total number of matches found: 64
# Percentage of unique combined names with matches: 1.13%
#                                                  Name  \
# 0                     ROYAL NORTHERN COLLEGE OF MUSIC
# 1                               HELIOS TECHNOLOGY LTD
# 2                       W.S. ATKINS INTERNATIONAL LTD
# 3                                      MEDICSIGHT PLC
# 4   THE POLICE AND CRIME COMMISSIONER FOR SOUTH YO...
# 5               UK HYDROGEN AND FUEL CELL ASSOCIATION
# 6                          ATKINS CONSULTANTS LIMITED
# 7              SCOTTISHPOWER RENEWABLE ENERGY LIMITED
# 8                                   D Young & Co  LLP
# 9                             IAN CATLING CONSULTANCY
# 10                                        TRL LIMITED
# 11                               UNIVERSITY OF LONDON
# 12  Cambridge University Hospitals NHS Foundation ...
# 13                       The University of Nottingham
# 14                        ROCKWELL COLLINS UK LIMITED
# 15                           PERSONTYLE GROUP LIMITED
# 16                         FIRST SOMERSET & AVON LTD.
# 17    MARKET & OPINION RESEARCH INTERNATIONAL LIMITED
# 18                            IT POWER CONSULTING LTD
# 19                                         ALSTOM LTD
#
#                                         Similar Names
# 0                              ROYAL COLLEGE OF MUSIC
# 1                                              Helios
# 2                                      ATKINS LIMITED
# 3                                  MEDICSIGHT LIMITED
# 4   POLICE AND CRIME COMMISSIONER FOR WEST YORKSHI...
# 5   THE SCOTTISH HYDROGEN AND FUEL CELL ASSOCIATIO...
# 6                                      ATKINS LIMITED
# 7                SCOTTISHPOWER RENEWABLE (UK) LIMITED
# 8                                    D Young & Co LLP
# 9                             Ian Catling Consultancy
# 10                                        TRL Limited
# 11                          CITY UNIVERSITY OF LONDON
# 12   OXFORD UNIVERSITY HOSPITALS NHS FOUNDATION TRUST
# 13  THE UNIVERSITY OF NOTTINGHAM; University of No...
# 14                         Rockwell Collins (UK) Ltd.
# 15                                 PERSONTYLE LIMITED
# 16                      FIRST SOMERSET & AVON LIMITED
# 17    Market & Opinion Research International Limited
# 18                                       IT Power Ltd
# 19                                   ALSTOM POWER LTD

# %%
import pandas as pd

# Function to group similar names based on a specified threshold
def group_similar_names(threshold=0.2):
    grouped_names = defaultdict(list)
    used_names = set()

    for i, name in enumerate(unique_combined_names):
        if name in used_names:
            continue

        # Get similar names based on the cosine similarity
        similar_names = [unique_combined_names[idx] for j, idx in enumerate(indices[i]) if distances[i][j] <= threshold and idx != i]

        if similar_names:  # Only consider if there are matches
            # Add to the group and mark as used
            grouped_names[name].extend(similar_names)
            used_names.add(name)
            used_names.update(similar_names)

    # Convert to DataFrame
    grouped_names_df = pd.DataFrame({
        'Unique Combination': grouped_names.keys(),
        'Matched Combinations': ['; '.join(names) for names in grouped_names.values()]
    })

    # Filter to show only items with matches
    grouped_names_df = grouped_names_df[grouped_names_df['Matched Combinations'].str.len() > 0]

    # Set the max column width to display full content
    pd.set_option('display.max_colwidth', None)

    # Output statistics
    total_matched_names = len(grouped_names_df)
    total_matches = grouped_names_df['Matched Combinations'].apply(lambda x: len(x.split('; '))).sum()

    print(f"Threshold: {threshold}")
    print(f"Total unique combined names with matches: {total_matched_names}")
    print(f"Total number of matches found: {total_matches}")
    print(f"Percentage of unique combined names with matches: {total_matched_names / total_unique_names * 100:.2f}%")

    # Display the first few groups with matches
    display(grouped_names_df.head(20))

# Example usage: play with the threshold
group_similar_names(threshold=0.1)
group_similar_names(threshold=0.3)
group_similar_names(threshold=0.5)
# Out:
# Threshold: 0.1
# Total unique combined names with matches: 26
# Total number of matches found: 28
# Percentage of unique combined names with matches: 0.48%
#                                                     Unique Combination  \
# 0                                                     ERICSSON LIMITED
# 1                                           Queen's University Belfast
# 2                                   OFFSHORE RENEWABLE ENERGY CATAPULT
# 3                                                          TRL LIMITED
# 4                                        BLACK MOUNTAIN INSULATION LTD
# 5   THE CHANCELLOR MASTERS AND SCHOLARS OF THE UNIVERSITY OF CAMBRIDGE
# 6                               CPL SCIENTIFIC PUBLISHING SERVICES LTD
# 7                                    UK CENTRE FOR ECOLOGY & HYDROLOGY
# 8                  MEDICINES AND HEALTHCARE PRODUCTS REGULATORY AGENCY
# 9                                          PRINTED ELECTRONICS LIMITED
# 10                                         ROCKWELL COLLINS UK LIMITED
# 11                                             IAN CATLING CONSULTANCY
# 12                                            University of Nottingham
# 13                                              National Energy Action
# 14                                                 ELEMENT SIX LIMITED
# 15                                    TATA STEEL UK CONSULTING LIMITED
# 16                                     ADVANCED DIGITAL INNOVATION LTD
# 17                                                    NOKIA UK LIMITED
# 18                                                        C.D. LIMITED
# 19                                                   D Young & Co  LLP
#
#                                                                                                                      Matched Combinations
# 0                                                                                                                        Ericsson Limited
# 1                                                                                                       THE QUEEN'S UNIVERSITY OF BELFAST
# 2                                                                                              Offshore Renewable Energy Catapult Limited
# 3                                                                                                                             TRL Limited
# 4                                                                                                           Black Mountain Insulation Ltd
# 5   The Chancellor, Masters and Scholars of the University of Cambridge; THE CHANCELLOR, MASTERS AND SCHOLARS OF THE UNIVERSITY OF OXFORD
# 6                                                                                                  CPL Scientific Publishing Services Ltd
# 7                                                                                                        Centre for Ecology and Hydrology
# 8                                                                                     Medicines and Healthcare products Regulatory Agency
# 9                                                                                                                 Printed Electronics Ltd
# 10                                                                                                             Rockwell Collins (UK) Ltd.
# 11                                                                                                                Ian Catling Consultancy
# 12                                                                             THE UNIVERSITY OF NOTTINGHAM; The University of Nottingham
# 13                                                                                                             NATIONAL ENERGY ACTION LBG
# 14                                                                                                               ELEMENT SIX (UK) LIMITED
# 15                                                                                                                  TATA STEEL UK LIMITED
# 16                                                                                                     ADVANCED DIGITAL INNOVATION UK LTD
# 17                                                                                                                 NOKIA R&D (UK) LIMITED
# 18                                                                                                                 I.C.T.S.(U.K.) LIMITED
# 19                                                                                                                       D Young & Co LLP
# Threshold: 0.3
# Total unique combined names with matches: 146
# Total number of matches found: 155
# Percentage of unique combined names with matches: 2.69%
#                                              Unique Combination  \
# 0                                           STOLI CATALYSTS LTD
# 1             POLICE AND CRIME COMMISSIONER FOR NORTH YORKSHIRE
# 2                                              ERICSSON LIMITED
# 3         UNIVERSITY HOSPITALS SOUTHAMPTON NHS FOUNDATION TRUST
# 4                                    Queen's University Belfast
# 5                                    OPEN SOURCE INNOVATION LTD
# 6                                               P1VITAL LIMITED
# 7                BAE SYSTEMS INTEGRATED SYSTEM TECHNOLOGIES LTD
# 8                                             COSTAIN GROUP PLC
# 9                   WEST MIDLANDS POLICE AND CRIME COMMISSIONER
# 10                                    DIGITAL LIFE SCIENCES LTD
# 11                              HONDA R & D EUROPE (UK) LIMITED
# 12                                           ENVIRONMENT AGENCY
# 13                                         UNIVERSITY OF LONDON
# 14                              ROYAL NORTHERN COLLEGE OF MUSIC
# 15                               WILD BERRY ENTERPRISES LIMITED
# 16  INSTITUTE OF CANCER RESEARCH: THE ROYAL CANCER HOSPITAL LBG
# 17                           OFFSHORE RENEWABLE ENERGY CATAPULT
# 18                                    STEM CELL SCIENCES UK LTD
# 19                                      Eaton Aerospace Limited
#
#                                                                                        Matched Combinations
# 0                                                                                        I.G. CATALYSTS LTD
# 1   POLICE AND CRIME COMMISSIONER FOR WEST YORKSHIRE; THE POLICE AND CRIME COMMISSIONER FOR SOUTH YORKSHIRE
# 2                                                                                          Ericsson Limited
# 3     Cambridge University Hospitals NHS Foundation Trust; OXFORD UNIVERSITY HOSPITALS NHS FOUNDATION TRUST
# 4                                                                         THE QUEEN'S UNIVERSITY OF BELFAST
# 5                                                                            OPEN SOURCE MANAGEMENT LIMITED
# 6                                                                                  P1VITAL PRODUCTS LIMITED
# 7                                                                        INTEGRATED SYSTEM TECHNOLOGIES LTD
# 8                                                                                               COSTAIN LTD
# 9                                                          POLICE AND CRIME COMMISSIONER FOR WEST YORKSHIRE
# 10                                                                                  Cambridge Life sciences
# 11                                                                               HONDA MOTOR EUROPE LIMITED
# 12                                                                     Food and Environment Research Agency
# 13       CITY UNIVERSITY OF LONDON; UNIVERSITY OF EAST LONDON; INSTITUTE OF EDUCATION, UNIVERSITY OF LONDON
# 14                                                                                   ROYAL COLLEGE OF MUSIC
# 15                                                                         WILD BERRY ENVIRONMENTAL LIMITED
# 16                                                                                   CANCER RESEARCH UK LBG
# 17                                                               Offshore Renewable Energy Catapult Limited
# 18                                                                                   Stem Cell Sciences PLC
# 19                                                                                            EATON LIMITED
# Threshold: 0.5
# Total unique combined names with matches: 732
# Total number of matches found: 1136
# Percentage of unique combined names with matches: 13.50%
#                                    Unique Combination  \
# 0                    OXFORD NANOPORE TECHNOLOGIES LTD
# 1   MINERVA PUBLIC RELATIONS & COMMUNICATIONS LIMITED
# 2                                  URBAN HAWK LIMITED
# 3                        FIRE SERVICE COLLEGE LIMITED
# 4                        DATA CENTRE ALLIANCE LIMITED
# 5                                 STOLI CATALYSTS LTD
# 6                                APPLIED GENOMICS LTD
# 7                                  Preston EV Limited
# 8          THE ROYAL COLLEGE OF GENERAL PRACTITIONERS
# 9                 OLDHAM METROPOLITAN BOROUGH COUNCIL
# 10                            MARINE MINERALS LIMITED
# 11                     CARDIFF SCINTIGRAPHICS LIMITED
# 12              ADVANCED MATERIAL DEVELOPMENT LIMITED
# 13   KINGSTON UNIVERSITY HIGHER EDUCATION CORPORATION
# 14                       ANALOX SENSOR TECHNOLOGY LTD
# 15                               London Economics Ltd
# 16                                      BMT GROUP LTD
# 17                                   DEEP TEK LIMITED
# 18                          OXFORD BROOKES UNIVERSITY
# 19                                   CRODA EUROPE LTD
#
#                                                                                                                                                                                                                                                                          Matched Combinations
# 0                                                                                                                                                                                                                                                                     OXFORD TECHNOLOGIES LTD
# 1                                                                                                                                                                                                                                                    MINERVA HEALTH & CARE COMMUNICATIONS LTD
# 2                                                                                                                                                                                                                                                                     Hawk Associates Limited
# 3                                                                                                                                                                                                                                                            SCOTTISH FIRE AND RESCUE SERVICE
# 4                                                                                                                                                                                                                                                           RESEARCH DATA ALLIANCE FOUNDATION
# 5                                                                                                                                                                                                                                                                          I.G. CATALYSTS LTD
# 6                                                                                                                                                                                                                                                                    Genomics England Limited
# 7                                                                                                                                                                                                                                                                   PRESTON SOLUTIONS LIMITED
# 8                                                                                                                                                                                       RCGP RSC-The Royal College of General Practitioners and Surveillance Centre; THE ROYAL COLLEGE OF ART
# 9                                                                                                                                                                       BARNSLEY METROPOLITAN BOROUGH COUNCIL; DONCASTER METROPOLITAN BOROUGH COUNCIL; STOCKPORT METROPOLITAN BOROUGH COUNCIL
# 10                                                                                                                                                                                                                                                                        IMERYS MINERALS LTD
# 11                                                                                                                                                                                                                                                                         CARDIFF UNIVERSITY
# 12                                                                                                                                                                                                         ADVANCED BIOPROCESS DEVELOPMENT LIMITED; ADVANCED CHEMISTRY DEVELOPMENT UK LIMITED
# 13  MIDDLESEX UNIVERSITY HIGHER EDUCATION CORPORATION; UNIVERSITY OF PORTSMOUTH HIGHER EDUCATION CORPORATION; THE UNIVERSITY OF HERTFORDSHIRE HIGHER EDUCATION CORPORATION; THE UNIVERSITY OF NORTHAMPTON HIGHER EDUCATION CORPORATION; ANGLIA RUSKIN UNIVERSITY HIGHER EDUCATION CORPORATION
# 14                                                                                                                                                                                                                                SENSOR TECHNOLOGY LIMITED; OXFORD SENSOR TECHNOLOGY LIMITED
# 15                                                                                                                                                                                            OXFORD ECONOMICS LIMITED; VIVID ECONOMICS LTD; LONDON SCHOOL OF ECONOMICS AND POLITICAL SCIENCE
# 16                                                                                                                                                                                                                          BMT SMART LIMITED; BMT ISIS LIMITED; BMT DEFENCE SERVICES LIMITED
# 17                                                                                                                                                                                                                                                                          X-TEK SYSTEMS LTD
# 18                                                                                                                                                                                                                                                                       University of Oxford
# 19                                                                                                                                                                                                                                                                    CRODA INTERNATIONAL PLC

# %%
import json
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
from collections import defaultdict

# Load the UK names data
with open('../data/raw/uk_data.json', 'r') as file:
    uk_data = json.load(file)

# Function to preprocess the names
def preprocess_name(name):
    name = name.lower()  # Convert to lowercase
    name = re.sub(r'\s+', ' ', name)  # Replace multiple spaces with a single space
    name = re.sub(r'[^\w\s]', '', name)  # Remove punctuation
    return name.strip()  # Strip leading and trailing whitespace

# Combine the name, short_name, and standardized_name fields
def combine_names(entry):
    combined_name = ' '.join(filter(None, [entry.get('name', ''), entry.get('short_name', ''), entry.get('standardized_name', '')]))
    return preprocess_name(combined_name)

# Create a list of combined names
combined_names = [combine_names(entry) for entry in uk_data]

# Remove exact duplicates to keep only unique combined names
unique_combined_names = list(set(combined_names))
total_unique_names = len(unique_combined_names)

# Vectorize the unique combined names using TF-IDF
vectorizer = TfidfVectorizer().fit(unique_combined_names)
name_vectors = vectorizer.transform(unique_combined_names)

# Use Nearest Neighbors to find similar names
nbrs = NearestNeighbors(n_neighbors=10, metric='cosine', algorithm='brute').fit(name_vectors)
distances, indices = nbrs.kneighbors(name_vectors)

# Group similar names based on the specified threshold
def group_similar_names(threshold=0.2):
    grouped_names = defaultdict(list)
    used_names = set()

    for i, name in enumerate(unique_combined_names):
        if name in used_names:
            continue

        # Get similar names based on the cosine similarity
        similar_names = [unique_combined_names[idx] for j, idx in enumerate(indices[i]) if distances[i][j] <= threshold and idx != i]

        if similar_names:  # Only consider if there are matches
            # Add to the group and mark as used
            grouped_names[name].extend(similar_names)
            used_names.add(name)
            used_names.update(similar_names)

    # Convert to DataFrame
    grouped_names_df = pd.DataFrame({
        'Unique Combination': grouped_names.keys(),
        'Matched Combinations': ['; '.join(names) for names in grouped_names.values()]
    })

    # Filter to show only items with matches
    grouped_names_df = grouped_names_df[grouped_names_df['Matched Combinations'].str.len() > 0]

    # Set the max column width to display full content
    pd.set_option('display.max_colwidth', None)

    # Output statistics
    total_matched_names = len(grouped_names_df)
    total_matches = grouped_names_df['Matched Combinations'].apply(lambda x: len(x.split('; '))).sum()

    print(f"Threshold: {threshold}")
    print(f"Total unique combined names with matches: {total_matched_names}")
    print(f"Total number of matches found: {total_matches}")
    print(f"Percentage of unique combined names with matches: {total_matched_names / total_unique_names * 100:.2f}%")

    # Display the first few groups with matches
    display(grouped_names_df.head(50))

# Example usage: play with the threshold
# group_similar_names(threshold=0.1)
group_similar_names(threshold=0.2)
# group_similar_names(threshold=0.3)
# group_similar_names(threshold=0.5)
# group_similar_names(threshold=0.7)
# group_similar_names(threshold=0.9)
# Out:
# Threshold: 0.2
# Total unique combined names with matches: 48
# Total number of matches found: 49
# Percentage of unique combined names with matches: 0.89%
#                                                     Unique Combination  \
# 0                                          alchemie technology limited
# 1                                uk hydrogen and fuel cell association
# 2                                                          bioniqs ltd
# 3                                 rollsroyce fuel cell systems limited
# 4                               scottishpower renewable energy limited
# 5                                        flexenable technology limited
# 6                                    university of the west of england
# 7                                          crops for the future uk cic
# 8                                                tata steel uk limited
# 9                                                               helios
# 10                 cambridge university hospitals nhs foundation trust
# 11                          offshore renewable energy catapult limited
# 12                                         materials solutions limited
# 13                                           queens university belfast
# 14                                              royal college of music
# 15                                            p1vital products limited
# 16                                           sensor technology limited
# 17                                             printed electronics ltd
# 18                                             it power consulting ltd
# 19                                                          scriptoria
# 20                                                  medicsight limited
# 21                                              national energy action
# 22                                            first somerset  avon ltd
# 23                                            university of nottingham
# 24                                                 element six limited
# 25                                          the english heritage trust
# 26  the chancellor masters and scholars of the university of cambridge
# 27                                              stem cell sciences plc
# 28                                         rockwell collins uk limited
# 29                                    centre for ecology and hydrology
# 30                                             canonical group limited
# 31                                          alan harper composites ltd
# 32                                           helpage international lbg
# 33                                                    alstom power ltd
# 34                                       smith  nephew medical limited
# 35                                         helrik and louw company ltd
# 36                               university of plymouth enterprise ltd
# 37                                  advanced digital innovation uk ltd
# 38                                  peter davidson consultancy limited
# 39                                               orion innovations llp
# 40                                              sagentia group limited
# 41                                                university of london
# 42                                              toshiba europe limited
# 43                                          atkins consultants limited
# 44                                              bird  bird belgium llp
# 45               the police and crime commissioner for south yorkshire
# 46                                                  persontyle limited
# 47                                             dnv services uk limited
#
#                                                                                    Matched Combinations
# 0                                                                                      alchemie limited
# 1                                                   the scottish hydrogen and fuel cell association ltd
# 2                                                                                       bioniqs limited
# 3                                                                                 fuel cell systems ltd
# 4                                                                    scottishpower renewable uk limited
# 5                                                                                    flexenable limited
# 6                                                             university of the west of england bristol
# 7                                                                          crops for the future limited
# 8                                                                      tata steel uk consulting limited
# 9                                                                                 helios technology ltd
# 10                                                     oxford university hospitals nhs foundation trust
# 11                                                                   offshore renewable energy catapult
# 12                                                                              materials solutions lbg
# 13                                                                     the queens university of belfast
# 14                                                                      royal northern college of music
# 15                                                                                      p1vital limited
# 16                                                                     oxford sensor technology limited
# 17                                                                          printed electronics limited
# 18                                                                                         it power ltd
# 19                                                                                       scriptoria ltd
# 20                                                                                       medicsight plc
# 21                                                                           national energy action lbg
# 22                                                                         first somerset  avon limited
# 23                                                                         the university of nottingham
# 24                                                                               element six uk limited
# 25                                                                                     english heritage
# 26                                      the chancellor masters and scholars of the university of oxford
# 27                                                                            stem cell sciences uk ltd
# 28                                                                              rockwell collins uk ltd
# 29                                                                     uk centre for ecology  hydrology
# 30                                                                                    canonical limited
# 31                                                                               alan harper composites
# 32                                                                             helpage international uk
# 33                                                                                           alstom ltd
# 34                                                                             smith  nephew uk limited
# 35                                                             helrik and louw and partners company ltd
# 36                                                                               university of plymouth
# 37                                                                      advanced digital innovation ltd
# 38                                                                                       davidson peter
# 39                                                                             orion innovations uk ltd
# 40                                                                                     sagentia limited
# 41                                                                            city university of london
# 42                                                                     toshiba international europe ltd
# 43                                                                                       atkins limited
# 44                                                                                       bird  bird llp
# 45  police and crime commissioner for west yorkshire; police and crime commissioner for north yorkshire
# 46                                                                             persontyle group limited
# 47                                                                                       dnv uk limited
