# %%
import os, sys, json
import numpy as np
import pandas as pd
import re
import ast
from pprint import pprint

# Move the current working directory to the root of the repository for consistency in file paths
def move_working_dir_to_repo_root(repo_name="orgsync"):
    """
    Move the current working directory to the root of the repository.
    """
    current_dir = os.getcwd()
    while os.path.basename(current_dir).lower() != repo_name:
        current_dir = os.path.dirname(current_dir)
    os.chdir(current_dir)
    print("Current working directory: ", os.getcwd())

move_working_dir_to_repo_root(repo_name="orgsync")

# Define the base path and the file paths 
org_data_paths_head = os.path.join("data", "raw", "all_scraped")
file_paths = {
    "cordis FP7": os.path.join(org_data_paths_head, "cordis/2024_07/FP7/organization.json"),
    "cordis Horizon 2020": os.path.join(org_data_paths_head, "cordis/2024_07/Horizon 2020/organization.json"),
    "cordis Horizon Europe": os.path.join(org_data_paths_head, "cordis/2024_07/Horizon Europe/organization.json"),
    "gtr": os.path.join(org_data_paths_head, "gtr/scraped/2024_07/organisations.json")
}
# Out:
# Current working directory:  c:\Users\dec2g\GitHub\OrgSync

# %%
def json_to_df(path:str):
    with open(path, 'r') as f:
        data = json.load(f)
    return pd.DataFrame(data)

# %%
def print_all_unique_vals_in_column(df, col_name):
    print("Unique values in column '{}':".format(col_name))
    unique_cols = df[col_name].unique()
    print(unique_cols)
    return unique_cols

# %% [markdown]
# Use the function below to verify that the included columns all have no unique values (all None).

# %%
def redundant_columns_gtr():
    df = json_to_df(file_paths["gtr"])
    print_all_unique_vals_in_column(df, "ext")
    print_all_unique_vals_in_column(df, "website")
    print_all_unique_vals_in_column(df, "regNumber")
    print_all_unique_vals_in_column(df, "outcomeid")

redundant_columns_gtr()
# Out:
# Unique values in column 'ext':
# [None]
# Unique values in column 'website':
# [None]
# Unique values in column 'regNumber':
# [None]
# Unique values in column 'outcomeid':
# [None]

# %% [markdown]
# ### Methods for extracting links from GtR data

# %%
def expand_dictionary_column(df, column_name:str):
    
    original_column = df[column_name].copy()
    # get new columns from dictionary
    new_columns = pd.json_normalize(original_column)

    df_level_one = pd.concat([new_columns, original_column], axis=1)
    return df_level_one

def map_each_dict_in_list_to_new_column(df_expanded, new_col_names):
    """
    Only works for address column
    """
    df_level_one = df_expanded
    col_of_dicts = []
    # go through each new column in level one
    for col in new_col_names:
        if type(df_level_one[col].iloc[0]) == list:
            print("true")
            # move each element of list to separate column
            list_to_cols = pd.json_normalize(df_level_one.copy()[col])
            col_of_dicts.append(list_to_cols)
    expanded_dfs = []
    for series in col_of_dicts:
        column_name = series.columns[0]
        print(f"Expanding column: {column_name}")
        expanded = expand_dictionary_column(series, column_name)
        expanded.drop(column_name, axis=1, inplace=True)
        expanded_dfs.append(expanded)

    expanded_df = pd.concat(expanded_dfs, axis=1)
    level_two = pd.concat([df_level_one, expanded_df], axis=1)
    level_two.drop(new_col_names, axis=1, inplace=True)
    return level_two

def expand_addresses(df):
    """
    Only works for address column
    """
    df_level_one = expand_dictionary_column(df, "addresses")
    new_col_names = [col for col in df_level_one.columns.to_list() if col not in original_df.columns.to_list()]
    print(new_col_names)
    df_level_one.head()
    return map_each_dict_in_list_to_new_column(df_level_one, new_col_names)

# %% [markdown]
# ### Start with GtR data only

# %%
df = json_to_df(file_paths["gtr"])
# leep only the columns "links", "id", "href"
df = df[["links", "id", "href", "created"]]

df.head()
# Out:
#                                                links  \
# 0  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
# 1  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
# 2  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
# 3  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
# 4  {'link': [{'href': 'http://gtr.ukri.org/gtr/ap...
#
#                                      id  \
# 0  5331B126-3AB4-4412-B56D-00E8F2796556
# 1  53331120-0290-49FA-A513-0286A214AF7A
# 2  77874202-2018-4677-8CFF-0868CD838659
# 3  77908BF8-1B2D-4D26-9119-155100E8B9C5
# 4  7794C645-9CC7-4913-A8DC-103AE0EFDD4B
#
#                                                 href        created
# 0  http://gtr.ukri.org/gtr/api/organisations/5331...  1704709432000
# 1  http://gtr.ukri.org/gtr/api/organisations/5333...  1704709432000
# 2  http://gtr.ukri.org/gtr/api/organisations/7787...  1704709432000
# 3  http://gtr.ukri.org/gtr/api/organisations/7790...  1704709432000
# 4  http://gtr.ukri.org/gtr/api/organisations/7794...  1704709432000

# %%
def expand_dictionary_column(df, column_name:str):
    
    original_column = df[column_name].copy()
    # get new columns from dictionary
    new_columns = pd.json_normalize(original_column)

    df_level_one = pd.concat([new_columns, original_column], axis=1).drop(column_name, axis=1)
    df_result = pd.concat([df, df_level_one], axis=1).drop(column_name, axis=1)
    return df_result

def expand_links_gtr(df):
    #! add dropna first?
    
    print(f"original shape: {df.shape}")
    df = df[["links", "id", "href"]]
    df.rename(columns={"href": "href_org"}, inplace=True)
    df = expand_dictionary_column(df, "links") # get nested dict
    df.rename(columns={"link": "links"}, inplace=True)
    df = df.explode("links") # get lists from dictionary. 
    df.reset_index(drop=True, inplace=True)
    #? We now have a dataframe where each link dict is in a separate row, and each ID appears multiple times if it has multiple links
    # df.dropna(inplace=True) #! may not be needed?
    # df.reset_index(drop=True, inplace=True) #! may not be needed?

    # normlise to get the fields of the link dict in separate columns
    normalised = pd.json_normalize(df["links"])
    normalised.rename(columns={"href": "href_link"}, inplace=True)
    df = pd.concat([df.reset_index(drop=True), normalised.reset_index(drop=True)], axis=1)
    return df

def pprint_first_row_for_column(df, column_name, i=0):
    print(f"First row for column '{column_name}':")
    pprint(df[column_name].iloc[i])

# %%
df = json_to_df(file_paths["gtr"])
#! do in chunks if doesn't fit to memory.

# remove 6000 rows from end
# df = df[:-60000]
df = expand_links_gtr(df)
df.head()
# Out:
# original shape: (69067, 11)
# C:\Users\dec2g\AppData\Local\Temp\ipykernel_48700\1701757378.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"href": "href_org"}, inplace=True)
#                                      id  \
# 0  5331B126-3AB4-4412-B56D-00E8F2796556
# 1  5331B126-3AB4-4412-B56D-00E8F2796556
# 2  5331B126-3AB4-4412-B56D-00E8F2796556
# 3  5331B126-3AB4-4412-B56D-00E8F2796556
# 4  5331B126-3AB4-4412-B56D-00E8F2796556
#
#                                             href_org  \
# 0  http://gtr.ukri.org/gtr/api/organisations/5331...
# 1  http://gtr.ukri.org/gtr/api/organisations/5331...
# 2  http://gtr.ukri.org/gtr/api/organisations/5331...
# 3  http://gtr.ukri.org/gtr/api/organisations/5331...
# 4  http://gtr.ukri.org/gtr/api/organisations/5331...
#
#                                                links  \
# 0  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 1  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 2  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 3  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 4  {'href': 'http://gtr.ukri.org/gtr/api/projects...
#
#                                            href_link      rel  start  end
# 0  http://gtr.ukri.org/gtr/api/projects/0D5DF2FF-...  PROJECT    NaN  NaN
# 1  http://gtr.ukri.org/gtr/api/projects/0D0F72CC-...  PROJECT    NaN  NaN
# 2  http://gtr.ukri.org/gtr/api/projects/0C6849FD-...  PROJECT    NaN  NaN
# 3  http://gtr.ukri.org/gtr/api/projects/C4059685-...  PROJECT    NaN  NaN
# 4  http://gtr.ukri.org/gtr/api/projects/F0E04953-...  PROJECT    NaN  NaN

# %%
# save to csv
df.to_csv(os.path.join("data", "processed", "gtr_links_expanded.csv"), index=False)

# %%
df.head(50)
# Out:
#                                       id  \
# 0   5331B126-3AB4-4412-B56D-00E8F2796556
# 1   5331B126-3AB4-4412-B56D-00E8F2796556
# 2   5331B126-3AB4-4412-B56D-00E8F2796556
# 3   5331B126-3AB4-4412-B56D-00E8F2796556
# 4   5331B126-3AB4-4412-B56D-00E8F2796556
# 5   5331B126-3AB4-4412-B56D-00E8F2796556
# 6   5331B126-3AB4-4412-B56D-00E8F2796556
# 7   5331B126-3AB4-4412-B56D-00E8F2796556
# 8   5331B126-3AB4-4412-B56D-00E8F2796556
# 9   5331B126-3AB4-4412-B56D-00E8F2796556
# 10  5331B126-3AB4-4412-B56D-00E8F2796556
# 11  5331B126-3AB4-4412-B56D-00E8F2796556
# 12  5331B126-3AB4-4412-B56D-00E8F2796556
# 13  5331B126-3AB4-4412-B56D-00E8F2796556
# 14  5331B126-3AB4-4412-B56D-00E8F2796556
# 15  5331B126-3AB4-4412-B56D-00E8F2796556
# 16  5331B126-3AB4-4412-B56D-00E8F2796556
# 17  5331B126-3AB4-4412-B56D-00E8F2796556
# 18  5331B126-3AB4-4412-B56D-00E8F2796556
# 19  5331B126-3AB4-4412-B56D-00E8F2796556
# 20  5331B126-3AB4-4412-B56D-00E8F2796556
# 21  5331B126-3AB4-4412-B56D-00E8F2796556
# 22  5331B126-3AB4-4412-B56D-00E8F2796556
# 23  5331B126-3AB4-4412-B56D-00E8F2796556
# 24  5331B126-3AB4-4412-B56D-00E8F2796556
# 25  5331B126-3AB4-4412-B56D-00E8F2796556
# 26  53331120-0290-49FA-A513-0286A214AF7A
# 27  53331120-0290-49FA-A513-0286A214AF7A
# 28  53331120-0290-49FA-A513-0286A214AF7A
# 29  77874202-2018-4677-8CFF-0868CD838659
# 30  77874202-2018-4677-8CFF-0868CD838659
# 31  77908BF8-1B2D-4D26-9119-155100E8B9C5
# 32  7794C645-9CC7-4913-A8DC-103AE0EFDD4B
# 33  77A41173-DC2B-4D30-A5E2-0B19BE4B8FD5
# 34  77A41173-DC2B-4D30-A5E2-0B19BE4B8FD5
# 35  77A41173-DC2B-4D30-A5E2-0B19BE4B8FD5
# 36  77A41173-DC2B-4D30-A5E2-0B19BE4B8FD5
# 37  77A41173-DC2B-4D30-A5E2-0B19BE4B8FD5
# 38  77A41173-DC2B-4D30-A5E2-0B19BE4B8FD5
# 39  53474E16-DA35-4007-9F07-1B6C0F32BBF6
# 40  5370084A-BDBF-4A7B-8E02-09B7DE95D01B
# 41  5370084A-BDBF-4A7B-8E02-09B7DE95D01B
# 42  5370084A-BDBF-4A7B-8E02-09B7DE95D01B
# 43  53700B68-0910-469D-A0CB-18A3316DF3F2
# 44  53700B68-0910-469D-A0CB-18A3316DF3F2
# 45  537D521C-3D73-458B-A054-196982ADD766
# 46  538761FB-F8B6-4799-9ADA-02F4EF15E8B3
# 47  538761FB-F8B6-4799-9ADA-02F4EF15E8B3
# 48  538761FB-F8B6-4799-9ADA-02F4EF15E8B3
# 49  538761FB-F8B6-4799-9ADA-02F4EF15E8B3
#
#                                              href_org  \
# 0   http://gtr.ukri.org/gtr/api/organisations/5331...
# 1   http://gtr.ukri.org/gtr/api/organisations/5331...
# 2   http://gtr.ukri.org/gtr/api/organisations/5331...
# 3   http://gtr.ukri.org/gtr/api/organisations/5331...
# 4   http://gtr.ukri.org/gtr/api/organisations/5331...
# 5   http://gtr.ukri.org/gtr/api/organisations/5331...
# 6   http://gtr.ukri.org/gtr/api/organisations/5331...
# 7   http://gtr.ukri.org/gtr/api/organisations/5331...
# 8   http://gtr.ukri.org/gtr/api/organisations/5331...
# 9   http://gtr.ukri.org/gtr/api/organisations/5331...
# 10  http://gtr.ukri.org/gtr/api/organisations/5331...
# 11  http://gtr.ukri.org/gtr/api/organisations/5331...
# 12  http://gtr.ukri.org/gtr/api/organisations/5331...
# 13  http://gtr.ukri.org/gtr/api/organisations/5331...
# 14  http://gtr.ukri.org/gtr/api/organisations/5331...
# 15  http://gtr.ukri.org/gtr/api/organisations/5331...
# 16  http://gtr.ukri.org/gtr/api/organisations/5331...
# 17  http://gtr.ukri.org/gtr/api/organisations/5331...
# 18  http://gtr.ukri.org/gtr/api/organisations/5331...
# 19  http://gtr.ukri.org/gtr/api/organisations/5331...
# 20  http://gtr.ukri.org/gtr/api/organisations/5331...
# 21  http://gtr.ukri.org/gtr/api/organisations/5331...
# 22  http://gtr.ukri.org/gtr/api/organisations/5331...
# 23  http://gtr.ukri.org/gtr/api/organisations/5331...
# 24  http://gtr.ukri.org/gtr/api/organisations/5331...
# 25  http://gtr.ukri.org/gtr/api/organisations/5331...
# 26  http://gtr.ukri.org/gtr/api/organisations/5333...
# 27  http://gtr.ukri.org/gtr/api/organisations/5333...
# 28  http://gtr.ukri.org/gtr/api/organisations/5333...
# 29  http://gtr.ukri.org/gtr/api/organisations/7787...
# 30  http://gtr.ukri.org/gtr/api/organisations/7787...
# 31  http://gtr.ukri.org/gtr/api/organisations/7790...
# 32  http://gtr.ukri.org/gtr/api/organisations/7794...
# 33  http://gtr.ukri.org/gtr/api/organisations/77A4...
# 34  http://gtr.ukri.org/gtr/api/organisations/77A4...
# 35  http://gtr.ukri.org/gtr/api/organisations/77A4...
# 36  http://gtr.ukri.org/gtr/api/organisations/77A4...
# 37  http://gtr.ukri.org/gtr/api/organisations/77A4...
# 38  http://gtr.ukri.org/gtr/api/organisations/77A4...
# 39  http://gtr.ukri.org/gtr/api/organisations/5347...
# 40  http://gtr.ukri.org/gtr/api/organisations/5370...
# 41  http://gtr.ukri.org/gtr/api/organisations/5370...
# 42  http://gtr.ukri.org/gtr/api/organisations/5370...
# 43  http://gtr.ukri.org/gtr/api/organisations/5370...
# 44  http://gtr.ukri.org/gtr/api/organisations/5370...
# 45  http://gtr.ukri.org/gtr/api/organisations/537D...
# 46  http://gtr.ukri.org/gtr/api/organisations/5387...
# 47  http://gtr.ukri.org/gtr/api/organisations/5387...
# 48  http://gtr.ukri.org/gtr/api/organisations/5387...
# 49  http://gtr.ukri.org/gtr/api/organisations/5387...
#
#                                                 links  \
# 0   {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 1   {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 2   {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 3   {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 4   {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 5   {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 6   {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 7   {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 8   {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 9   {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 10  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 11  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 12  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 13  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 14  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 15  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 16  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 17  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 18  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 19  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 20  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 21  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 22  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 23  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 24  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 25  {'href': 'http://gtr.ukri.org/gtr/api/persons/...
# 26  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 27  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 28  {'href': 'http://gtr.ukri.org/gtr/api/persons/...
# 29  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 30  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 31  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 32  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 33  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 34  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 35  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 36  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 37  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 38  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 39  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 40  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 41  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 42  {'href': 'http://gtr.ukri.org/gtr/api/persons/...
# 43  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 44  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 45  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 46  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 47  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 48  {'href': 'http://gtr.ukri.org/gtr/api/projects...
# 49  {'href': 'http://gtr.ukri.org/gtr/api/projects...
#
#                                             href_link       rel  start  end
# 0   http://gtr.ukri.org/gtr/api/projects/0D5DF2FF-...   PROJECT    NaN  NaN
# 1   http://gtr.ukri.org/gtr/api/projects/0D0F72CC-...   PROJECT    NaN  NaN
# 2   http://gtr.ukri.org/gtr/api/projects/0C6849FD-...   PROJECT    NaN  NaN
# 3   http://gtr.ukri.org/gtr/api/projects/C4059685-...   PROJECT    NaN  NaN
# 4   http://gtr.ukri.org/gtr/api/projects/F0E04953-...   PROJECT    NaN  NaN
# 5   http://gtr.ukri.org/gtr/api/projects/D9A401D9-...   PROJECT    NaN  NaN
# 6   http://gtr.ukri.org/gtr/api/projects/EC918CE3-...   PROJECT    NaN  NaN
# 7   http://gtr.ukri.org/gtr/api/projects/ADB18319-...   PROJECT    NaN  NaN
# 8   http://gtr.ukri.org/gtr/api/projects/DCFE5B2E-...   PROJECT    NaN  NaN
# 9   http://gtr.ukri.org/gtr/api/projects/1E0BB71C-...   PROJECT    NaN  NaN
# 10  http://gtr.ukri.org/gtr/api/projects/2294E699-...   PROJECT    NaN  NaN
# 11  http://gtr.ukri.org/gtr/api/projects/A45E2042-...   PROJECT    NaN  NaN
# 12  http://gtr.ukri.org/gtr/api/projects/096F035D-...   PROJECT    NaN  NaN
# 13  http://gtr.ukri.org/gtr/api/projects/6C78CAA4-...   PROJECT    NaN  NaN
# 14  http://gtr.ukri.org/gtr/api/projects/E0B948B2-...   PROJECT    NaN  NaN
# 15  http://gtr.ukri.org/gtr/api/projects/1F792DF3-...   PROJECT    NaN  NaN
# 16  http://gtr.ukri.org/gtr/api/projects/963F82CE-...   PROJECT    NaN  NaN
# 17  http://gtr.ukri.org/gtr/api/projects/A8502FDF-...   PROJECT    NaN  NaN
# 18  http://gtr.ukri.org/gtr/api/projects/3AE6C680-...   PROJECT    NaN  NaN
# 19  http://gtr.ukri.org/gtr/api/projects/0A2B35E7-...   PROJECT    NaN  NaN
# 20  http://gtr.ukri.org/gtr/api/projects/716EFB49-...   PROJECT    NaN  NaN
# 21  http://gtr.ukri.org/gtr/api/projects/18B5E7EF-...   PROJECT    NaN  NaN
# 22  http://gtr.ukri.org/gtr/api/projects/13A0CD0B-...   PROJECT    NaN  NaN
# 23  http://gtr.ukri.org/gtr/api/projects/F41D42DE-...   PROJECT    NaN  NaN
# 24  http://gtr.ukri.org/gtr/api/projects/F7EC062A-...   PROJECT    NaN  NaN
# 25  http://gtr.ukri.org/gtr/api/persons/0CB4A538-A...  EMPLOYEE    NaN  NaN
# 26  http://gtr.ukri.org/gtr/api/projects/B012B0D9-...   PROJECT    NaN  NaN
# 27  http://gtr.ukri.org/gtr/api/projects/B0359A89-...   PROJECT    NaN  NaN
# 28  http://gtr.ukri.org/gtr/api/persons/951DAD79-1...  EMPLOYEE    NaN  NaN
# 29  http://gtr.ukri.org/gtr/api/projects/6272E5E8-...   PROJECT    NaN  NaN
# 30  http://gtr.ukri.org/gtr/api/projects/34D4F9E9-...   PROJECT    NaN  NaN
# 31  http://gtr.ukri.org/gtr/api/projects/86D3E475-...   PROJECT    NaN  NaN
# 32  http://gtr.ukri.org/gtr/api/projects/B6328B17-...   PROJECT    NaN  NaN
# 33  http://gtr.ukri.org/gtr/api/projects/7BFFAA57-...   PROJECT    NaN  NaN
# 34  http://gtr.ukri.org/gtr/api/projects/261693D8-...   PROJECT    NaN  NaN
# 35  http://gtr.ukri.org/gtr/api/projects/A5C71609-...   PROJECT    NaN  NaN
# 36  http://gtr.ukri.org/gtr/api/projects/024FE285-...   PROJECT    NaN  NaN
# 37  http://gtr.ukri.org/gtr/api/projects/19B1184B-...   PROJECT    NaN  NaN
# 38  http://gtr.ukri.org/gtr/api/projects/2316473B-...   PROJECT    NaN  NaN
# 39  http://gtr.ukri.org/gtr/api/projects/A1026C17-...   PROJECT    NaN  NaN
# 40  http://gtr.ukri.org/gtr/api/projects/DDBC1424-...   PROJECT    NaN  NaN
# 41  http://gtr.ukri.org/gtr/api/projects/248C1BF6-...   PROJECT    NaN  NaN
# 42  http://gtr.ukri.org/gtr/api/persons/77F68725-5...  EMPLOYEE    NaN  NaN
# 43  http://gtr.ukri.org/gtr/api/projects/DD73BF27-...   PROJECT    NaN  NaN
# 44  http://gtr.ukri.org/gtr/api/projects/96E64EB6-...   PROJECT    NaN  NaN
# 45  http://gtr.ukri.org/gtr/api/projects/C34CB6BB-...   PROJECT    NaN  NaN
# 46  http://gtr.ukri.org/gtr/api/projects/BA986004-...   PROJECT    NaN  NaN
# 47  http://gtr.ukri.org/gtr/api/projects/984AC337-...   PROJECT    NaN  NaN
# 48  http://gtr.ukri.org/gtr/api/projects/99E40BE4-...   PROJECT    NaN  NaN
# 49  http://gtr.ukri.org/gtr/api/projects/BC739729-...   PROJECT    NaN  NaN

# %%
print_all_unique_vals_in_column(df, "rel")
print_all_unique_vals_in_column(df, "start")
print_all_unique_vals_in_column(df, "end")
# Out:
# Unique values in column 'rel':
# ['PROJECT' 'EMPLOYEE' nan]
# Unique values in column 'start':
# [nan]
# Unique values in column 'end':
# [nan]
# array([nan])

# %% [markdown]
# ### Links in GtR data
# * href_org: link to the organisation in the GtR database
# * PROJECT: link to a project related to the organisation
#   * project id: unique identifier for the project
#   * various key word links e.g.
#     * "<x>_PER" : link to a person related to the project by role <x> (PI, COI etc.)
#     * "<x>_ORG" : link to an organisation related to the project by role <x> (lead, collab etc.)
#     * funding information
#     * IMPACT_SUMMARY
#     * PUBLICATION : links to all publications related to the project e.g.
#       * <ns1:link ns1:href="http://gtr.ukri.org/gtr/api/outcomes/publications/44A93C83-5416-439B-AAC3-ACD3AE30B2A7" ns1:rel="PUBLICATION"/>
#         * title
#         * type e.g. journal article, conference paper etc.
#         * dataPublished
#         * author : author name as one string, sometimes "name (coauthor)"
#         *
# * EMPLOYEE: link to employee related to the organisation
#   * id: unique identifier for the employee
#   * firstName
#   * otherNames
#   * surname
#   * various key word links (could expand as before)

# %%
pprint_first_row_for_column(df, "links")
pprint_first_row_for_column(df, "links", i=25)
# Out:
# First row for column 'links':
# {'end': None,
#  'href': 'http://gtr.ukri.org/gtr/api/projects/0D5DF2FF-B732-4218-B0E3-4FFBF3DDC906',
#  'otherAttributes': {},
#  'rel': 'PROJECT',
#  'start': None}
# First row for column 'links':
# {'end': None,
#  'href': 'http://gtr.ukri.org/gtr/api/persons/0CB4A538-AC14-4394-A10F-C9F955033EF3',
#  'otherAttributes': {},
#  'rel': 'EMPLOYEE',
#  'start': None}

# %% [markdown]
# # Next, use requests to access information from link hrefs
#
# Try https://github.com/nestauk/gtr

# %%
# import gtr
# https://gtr.ukri.org/resources/GtR-2-API-v1.7.4.pdf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import gtr
#
# File c:\Users\dec2g\anaconda3\envs\dan-env\lib\site-packages\gtr\__init__.py:10
#       1 __all__ = [
#       2     "gtr.services.funds.Funds",
#       3     "gtr.services.organisations.Organisations",
#    (...)
#       6     "gtr.services.publications.Publications"
#       7 ]
#       8 __version__ = "0.1.1"
# ---> 10 from gtr.services.base import _Service
#      11 from gtr.services.funds import Funds
#      12 from gtr.services.organisations import Organisations
#
# File c:\Users\dec2g\anaconda3\envs\dan-env\lib\site-packages\gtr\services\base.py:1
# ----> 1 import requests
#       3 from .. import __version__
#       6 class _Service(object):
#
# File c:\Users\dec2g\anaconda3\envs\dan-env\lib\site-packages\requests\__init__.py:58
#      55 except ImportError:
#      56     pass
# ---> 58 from . import utils
#      59 from .models import Request, Response, PreparedRequest
#      60 from .api import request, get, head, post, patch, put, delete, options
#
# File c:\Users\dec2g\anaconda3\envs\dan-env\lib\site-packages\requests\utils.py:30
#      26 from .compat import parse_http_list as _parse_list_header
#      27 from .compat import (quote, urlparse, bytes, str, OrderedDict, unquote, is_py2,
#      28                      builtin_str, getproxies, proxy_bypass, urlunparse,
#      29                      basestring)
# ---> 30 from .cookies import RequestsCookieJar, cookiejar_from_dict
#      31 from .structures import CaseInsensitiveDict
#      32 from .exceptions import InvalidURL, FileModeWarning
#
# File c:\Users\dec2g\anaconda3\envs\dan-env\lib\site-packages\requests\cookies.py:164
#     159 class CookieConflictError(RuntimeError):
#     160     """There are two cookies that meet the criteria specified in the cookie jar.
#     161     Use .get and .set and include domain and path args in order to be more specific."""
# --> 164 class RequestsCookieJar(cookielib.CookieJar, collections.MutableMapping):
#     165     """Compatibility class; is a cookielib.CookieJar, but exposes a dict
#     166     interface.
#     167
#    (...)
#     179     .. warning:: dictionary operations that are normally O(1) may be O(n).
#     180     """
#     181     def get(self, name, default=None, domain=None, path=None):
#
# AttributeError: module 'collections' has no attribute 'MutableMapping'
