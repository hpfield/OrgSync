# %%
import os
import pandas as pd
import numpy as np
import re

# %%
# Define the project root as the directory containing the notebook, or adjust as needed
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))

# Define the path to the JSON file relative to the project root
json_file_path = os.path.join(PROJECT_ROOT, 'data', 'raw', 'all_scraped', 'cordis', '2024_07', 'Horizon 2020', 'project.json')

# Load the JSON file into a pandas DataFrame
def load_json_as_dataframe(file_path):
    return pd.read_json(file_path, orient='records')

# Load the combined_organizations.json file
combined_organizations = load_json_as_dataframe(json_file_path)

# Now, combined_organizations_df contains the loaded data in a pandas DataFrame
print(combined_organizations.info())  # This will give you an overview of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35386 entries, 0 to 35385
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   acronym             35386 non-null  object
#  1   contentUpdateDate   35386 non-null  object
#  2   ecMaxContribution   35386 non-null  float64
#  3   ecSignatureDate     35386 non-null  object
#  4   endDate             35386 non-null  object
#  5   frameworkProgramme  35386 non-null  object
#  6   fundingScheme       35386 non-null  object
#  7   grantDoi            35386 non-null  object
#  8   id                  35386 non-null  int64
#  9   legalBasis          35386 non-null  object
#  10  masterCall          35386 non-null  object
#  11  nature              35386 non-null  object
#  12  objective           35386 non-null  object
#  13  rcn                 35386 non-null  int64
#  14  startDate           35386 non-null  object
#  15  status              35386 non-null  object
#  16  subCall             35386 non-null  object
#  17  title               35386 non-null  object
#  18  topics              35386 non-null  object
#  19  totalCost           35386 non-null  float64
# dtypes: float64(2), int64(2), object(16)
# memory usage: 5.4+ MB
# None

# %%
pd.set_option('display.max_columns', None)

combined_organizations.head()
# Out:
#              acronym    contentUpdateDate  ecMaxContribution ecSignatureDate  \
# 0    FAMilyDECisions  2022-08-15 14:52:11           239191.2      2015-10-30
# 1           simpetmr  2022-09-21 10:19:42           212194.8      2018-03-23
# 2  Human Glymphatics  2023-07-23 22:53:46           200194.8      2018-04-10
# 3      INMANCAP_2019  2022-08-25 16:34:05           478177.5      2018-11-28
# 4   INMANCAP 2017_18  2022-08-23 22:28:06           909905.0      2017-01-31
#
#       endDate frameworkProgramme  fundingScheme        grantDoi      id  \
# 0  2019-09-30              H2020     MSCA-IF-GF  10.3030/657030  657030
# 1  2021-09-22              H2020  MSCA-IF-EF-SE  10.3030/796759  796759
# 2  2020-09-23              H2020        MSCA-IF  10.3030/798131  798131
# 3  2019-12-31              H2020            CSA  10.3030/831207  831207
# 4  2018-12-31              H2020            CSA  10.3030/739564  739564
#
#       legalBasis                masterCall nature  \
# 0  H2020-EU.1.3.        H2020-MSCA-IF-2014
# 1  H2020-EU.1.3.        H2020-MSCA-IF-2017
# 2  H2020-EU.1.3.        H2020-MSCA-IF-2017
# 3  H2020-EU.2.3.       H2020-EEN-SGA3-2018
# 4  H2020-EU.2.3.  H2020-EEN-SGA2-2017-2018
#
#                                            objective     rcn   startDate  \
# 0  During the last decades, Spain has experienced...  199678  2016-10-01
# 1  Imaging of physiological functions in the livi...  215481  2019-03-11
# 2  Sufficient sleep is a key determinant of healt...  215616  2018-04-01
# 3  The overall objectives of the project are to d...  220751  2019-01-01
# 4  The overall objectives of the project are to d...  208215  2017-01-01
#
#        status                   subCall  \
# 0      CLOSED        H2020-MSCA-IF-2014
# 1      CLOSED        H2020-MSCA-IF-2017
# 2  TERMINATED        H2020-MSCA-IF-2017
# 3      CLOSED       H2020-EEN-SGA3-2018
# 4      CLOSED  H2020-EEN-SGA2-2017-2018
#
#                                                title           topics  \
# 0  Family formation decisions and gender attitude...  MSCA-IF-2014-GF
# 1  Development of quantification procedures for s...     MSCA-IF-2017
# 2  Effects of sleep deprivation and adrenergic in...     MSCA-IF-2017
# 3  Enhancing innovation management capacity of SM...     H2020EENSGA3
# 4  Enhancing innovation management capacity of SM...   H2020-SGA2-EEN
#
#    totalCost
# 0   239191.2
# 1   212194.8
# 2   200194.8
# 3   478177.5
# 4   909905.0

# %%
# Define the project root as the directory containing the notebook, or adjust as needed
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))

# Define the path to the JSON file relative to the project root
json_file_path = os.path.join(PROJECT_ROOT, 'data', 'raw', 'all_scraped', 'cordis', '2024_07', 'Horizon 2020', 'euroSciVoc.json')

# Load the JSON file into a pandas DataFrame
def load_json_as_dataframe(file_path):
    return pd.read_json(file_path, orient='records')

# Load the combined_organizations.json file
euro_sci_voc = load_json_as_dataframe(json_file_path)

# Now, combined_organizations_df contains the loaded data in a pandas DataFrame
print(euro_sci_voc.info())  # This will give you an overview of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120701 entries, 0 to 120700
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   euroSciVocCode         120701 non-null  object
#  1   euroSciVocDescription  120701 non-null  object
#  2   euroSciVocPath         120701 non-null  object
#  3   euroSciVocTitle        120701 non-null  object
#  4   projectID              120701 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 4.6+ MB
# None

# %%
# Define the project root as the directory containing the notebook, or adjust as needed
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))

# Define the path to the JSON file relative to the project root
json_file_path = os.path.join(PROJECT_ROOT, 'data', 'raw', 'all_scraped', 'cordis', '2024_07', 'Horizon 2020', 'topics.json')

# Load the JSON file into a pandas DataFrame
def load_json_as_dataframe(file_path):
    return pd.read_json(file_path, orient='records')

# Load the combined_organizations.json file
topics = load_json_as_dataframe(json_file_path)

# Now, combined_organizations_df contains the loaded data in a pandas DataFrame
print(topics.info())  # This will give you an overview of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35386 entries, 0 to 35385
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   projectID  35386 non-null  int64
#  1   title      35386 non-null  object
#  2   topic      35386 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 829.5+ KB
# None
