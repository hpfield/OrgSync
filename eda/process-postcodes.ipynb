# %%
from uk_postcodes_parsing import ukpostcode, fix, postcode_utils
import pandas as pd
import json
import numpy as np
import re, os, sys
from pprint import pprint

def move_working_dir_to_repo_root(repo_name="orgsync"):
    """
    Move the current working directory to the root of the repository.
    """
    current_dir = os.getcwd()
    while os.path.basename(current_dir).lower() != repo_name:
        current_dir = os.path.dirname(current_dir)
    os.chdir(current_dir)
    print("Current working directory: ", os.getcwd())

move_working_dir_to_repo_root(repo_name="orgsync")
# Out:
# Current working directory:  /home/ubuntu/OrgSync

# %%
### Load full gtr and cordis datasets (update the cleaning code...)
data_dir = os.path.join("data", "raw")
gtr_path = os.path.join(data_dir, "gtr_data.json")
cordis_path = os.path.join(data_dir, "uk_data.json")

# with open(gtr_path, "r") as f:
#     gtr_data = json.load(f)

# with open(cordis_path, "r") as f:
#     cordis_data = json.load(f)

def rename_fields(data, field_renaming):
    for record in data:
        for old_field, new_field in field_renaming.items():
            record[new_field] = record.pop(old_field)
    return data

def keep_fields(original_data, fields_to_keep, inplace=False):
    # avoid modifying original json by accident!
    if not inplace:
        data = original_data.copy()
    else:
        data = original_data
    for record in data:
        for field in list(record.keys()):
            if field not in fields_to_keep:
                record.pop(field)
    return data

# def parse_postcode(postcode):
#     parsed = ukpostcode.parse_from_corpus(postcode, attempt_fix=True)
#     # parsed is an empty list if the postcode is invalid
#     if len(parsed) == 0:
#         return None
#     return parsed[0].__dict__

def create_single_valued_field(data, field_name, value):
    for record in data:
        record[field_name] = value
    return data


def convert_field_to_str(data, field):
    """
    convert all values in a field to strings
    """
    for record in data:
        print(record[field])
        print(type(record[field]))
        record[field] = str(record[field])
        print(record[field])
    return data

data_path = os.path.join("data","splink","all_data.json")
with open(data_path, "r") as f:
    data = json.load(f)

postcodes = keep_fields(data, ["dataset", "unique_id", "postcode"])


## Update cleaning code...
# gtr_field_renaming = {
#     "id": "unique_id",
#     "postCode": "postcode",
# }

# cordis_field_renaming = {
#     "organisationID": "unique_id",
#     # "postCode": "postcode",
# }

# gtr_data = rename_fields(gtr_data, gtr_field_renaming)
# cordis_data = rename_fields(cordis_data, cordis_field_renaming)

# create_single_valued_field(gtr_data, "dataset", "gtr")
# create_single_valued_field(cordis_data, "dataset", "cordis")


# fields_to_keep = ["dataset","unique_id", "postcode"]

# # isolate poctcodes, keeping ids to link back to original data
# cordis_postcodes = keep_fields(cordis_data, fields_to_keep)
# gtr_postcodes = keep_fields(gtr_data, fields_to_keep)

# # combine
# all_postcodes = cordis_postcodes + gtr_postcodes

# df = pd.DataFrame(all_postcodes)
# df.tail()

# %%
def remove_whitespace(postcode):
    return re.sub(r"\s+", "", postcode)

def parse_postcode(postcode):
    parsed = try_parsing(postcode)
    if parsed:
        return parsed
    parsed = try_parsing(remove_whitespace(postcode))
    return parsed

        
def try_parsing(postcode):
    try:
        parsed = a(postcode)
        if parsed:
            return parsed
    except Exception as e:
        pass
    try:
        parsed = b(postcode)
        if parsed:
            return parsed
    except Exception as e:
        pass
    try:
        parsed = c(postcode)
        if parsed:
            return parsed
    except Exception as e:
        pass
    else:
        return None

def a(postcode):
    try:
        parsed = ukpostcode.parse(postcode)
        return parsed[0].__dict__
    except Exception as e:
        pass
    else:
        return None
    
def b(postcode):
    try:
        parsed = ukpostcode.parse_from_corpus(postcode, attempt_fix=True)
        return parsed[0].__dict__
    except Exception as e:
        pass
    else:
        return None
    
def c(postcode):
    try:
        parsed = ukpostcode.parse_from_corpus(postcode, attempt_fix=True, try_all_fix_options=True)
        return parsed[0].__dict__
    except Exception as e:
        pass
    else:
        return None



def create_parsed_postcodes_fields(data):
    """
    Takes in json of records with fields "unique_id" and "postcode". Parses postcodes with
    ukpostcode library and adds parsed postcode fields to each record.

    If len(parse_postcode) == 0, then the postcode is not valid, and the record should be 
    populated with None values.
    
    e.g.
    parse_postcode("SW1A 1AA") ->
        {'original': 'SW1A 1AA',
        'postcode': 'SW1A 1AA',
        'incode': '1AA',
        'outcode': 'SW1A',
        'area': 'SW',
        'district': 'SW1',
        'sub_district': 'SW1A',
        'sector': 'SW1A 1',
        'unit': 'AA',
        'fix_distance': 0,
        'is_in_ons_postcode_directory': True} 
    """
    empty_fields = {
            "original": None,  
            "postcode": None,
            "incode": None,
            "outcode": None,
            "area": None,
            "district": None,
            "sub_district": None,
            "sector": None,
            "unit": None,
            "fix_distance": None,
            "is_in_ons_postcode_directory": None
    }

    for record in data:
        if not record["postcode"]:
            record.update(empty_fields)
            continue
        parsed = parse_postcode(record["postcode"])
        if not parsed:
            record.update(empty_fields)
            continue
        record.update(parsed)

    # for all fields other than unique_id and dataset, modify to "parsed." + field
    for record in data:
        for field in list(record.keys()):
            if field not in ["unique_id", "dataset"]:
                record["parsed." + field] = record.pop(field)
    return data

all_postcodes = create_parsed_postcodes_fields(postcodes)
all_postcodes
# save to json
save_path = os.path.join("data", "splink", "parsed_postcodes.json")
# check if path exists, else create
if not os.path.exists(os.path.dirname(save_path)):
    os.makedirs(os.path.dirname(save_path))
with open(save_path, "w") as f:
    json.dump(all_postcodes, f, indent=2)
# Out:
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'le13 opb' => 'LE13 0PB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'le13 opb' => 'LE13 0PB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'rh13 osz' => 'RH13 0SZ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'rh13 osz' => 'RH13 0SZ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'rh13 osz' => 'RH13 0SZ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'rh13 osz' => 'RH13 0SZ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'cw10 ohx' => 'CW10 0HX'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'cw10 ohx' => 'CW10 0HX'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ox4 2 hn
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: w1 t 5 hd
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'le13 opb' => 'LE13 0PB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'le13 opb' => 'LE13 0PB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'le13 opb' => 'LE13 0PB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'le13 opb' => 'LE13 0PB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'le13 opb' => 'LE13 0PB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'le13 opb' => 'LE13 0PB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'hu13 ojg' => 'HU13 0JG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'hu13 ojg' => 'HU13 0JG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'pe28 onj' => 'PE28 0NJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'pe28 onj' => 'PE28 0NJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox2 ojx' => 'OX2 0JX'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox2 ojx' => 'OX2 0JX'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: cro 2bx
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: cro 2bx
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'pe12 oaj' => 'PE12 0AJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'pe12 oaj' => 'PE12 0AJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'cb25 onw' => 'CB25 0NW'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'cb25 onw' => 'CB25 0NW'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh3 7a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh37a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: hu 15 1ll
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '15 1ll' => 'I5 1LL'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'np4 ohz' => 'NP4 0HZ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'np4 ohz' => 'NP4 0HZ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'np4 ohz' => 'NP4 0HZ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'np4 ohz' => 'NP4 0HZ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x16 1tq' => 'OX16 1TQ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x16 1tq' => 'OX16 1TQ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'eciv inq' => 'EC1V 1NQ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'eciv inq' => 'EC1V 1NQ'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh3 7a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh37a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: e14 9shb
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ni 9jy' => 'N1 9JY'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ni 9jy' => 'N1 9JY'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'pe12onr' => 'PE12 0NR'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'pe12onr' => 'PE12 0NR'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ha6 2 ue
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'le13 opb' => 'LE13 0PB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'le13 opb' => 'LE13 0PB'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: me15 6 le
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'mk43 oaj' => 'MK43 0AJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'mk43 oaj' => 'MK43 0AJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'b10 ohj' => 'B10 0HJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'b10 ohj' => 'B10 0HJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'le13 opb' => 'LE13 0PB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'le13 opb' => 'LE13 0PB'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: y0105 ny
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'y0105ny' => 'YO10 5NY'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'y0105ny' => 'YO10 5NY'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x39 4tw' => 'OX39 4TW'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x39 4tw' => 'OX39 4TW'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: m40 5 bp
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'hg3 ipy' => 'HG3 1PY'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'hg3 ipy' => 'HG3 1PY'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: hu 15 1ll
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '15 1ll' => 'I5 1LL'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: sn 3 4 te
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: kt15 2 uf
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'mk43 oaj' => 'MK43 0AJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'mk43 oaj' => 'MK43 0AJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'b10 ohj' => 'B10 0HJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'b10 ohj' => 'B10 0HJ'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ne 1hf
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ne1hf
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: cwi 6gu
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: cwi 6gu
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'y010 5dd' => 'YO10 5DD'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'y010 5dd' => 'YO10 5DD'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ne3 3 ls
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wcin 2eb' => 'WC1N 2EB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wcin 2eb' => 'WC1N 2EB'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: le11 3x2
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: le113x2
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: m40 5 bp
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: bs 49 4ap
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'le13 opb' => 'LE13 0PB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'le13 opb' => 'LE13 0PB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'y025 9ed' => 'YO25 9ED'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'y025 9ed' => 'YO25 9ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh 54 6 gu
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: bs 49 4ap
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'b10 ohj' => 'B10 0HJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'b10 ohj' => 'B10 0HJ'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: cbf 5ry
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: cbf5ry
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox2 ojb' => 'OX2 0JB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox2 ojb' => 'OX2 0JB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ts24 oux' => 'TS24 0UX'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ts24 oux' => 'TS24 0UX'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox2 ojx' => 'OX2 0JX'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox2 ojx' => 'OX2 0JX'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ox5 pf
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ox5pf
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'le13 opb' => 'LE13 0PB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'le13 opb' => 'LE13 0PB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'bt17 oql' => 'BT17 0QL'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'bt17 oql' => 'BT17 0QL'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: cwi 6gu
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: cwi 6gu
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ne 1hf
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ne1hf
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 's031 4ra' => 'SO31 4RA'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 's031 4ra' => 'SO31 4RA'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh3 7a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh37a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: cwi 6gu
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: cwi 6gu
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: cwi 6gu
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: cwi 6gu
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 's0166yd' => 'SO16 6YD'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 's0166yd' => 'SO16 6YD'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh9 1 pl
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'po8 oyt' => 'PO8 0YT'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'po8 oyt' => 'PO8 0YT'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: bs 49 4ap
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'np4 ohz' => 'NP4 0HZ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'np4 ohz' => 'NP4 0HZ'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ox5 pf
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ox5pf
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ox5 pf
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ox5pf
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ox5 pf
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ox5pf
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ne 1hf
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ne1hf
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'swie 6qp' => 'SW1E 6QP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'swie 6qp' => 'SW1E 6QP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'bd7 idp' => 'BD7 1DP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'bd7 idp' => 'BD7 1DP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'le13 opb' => 'LE13 0PB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'le13 opb' => 'LE13 0PB'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'mk43 oaj' => 'MK43 0AJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'mk43 oaj' => 'MK43 0AJ'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: sg86p2
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: sg86p2
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: sp3 66hf
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wc1 n1by
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'y010 3pg' => 'YO10 3PG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'y010 3pg' => 'YO10 3PG'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: cwi 6gu
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: cwi 6gu
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'hg3 ipy' => 'HG3 1PY'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'hg3 ipy' => 'HG3 1PY'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ng21 9 pr
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x16 1tq' => 'OX16 1TQ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x16 1tq' => 'OX16 1TQ'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ox5 pf
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ox5pf
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: bs 49 4ap
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh3 7a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh37a
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'pe12 oaj' => 'PE12 0AJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'pe12 oaj' => 'PE12 0AJ'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: slo 9pn
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: slo 9pn
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'cw10 ohx' => 'CW10 0HX'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'cw10 ohx' => 'CW10 0HX'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 's031 4ra' => 'SO31 4RA'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 's031 4ra' => 'SO31 4RA'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh3 7a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh37a
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'b3 iqz' => 'B3 1QZ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'b3 iqz' => 'B3 1QZ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: rg26 sgj
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: rg26sgj
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh3 7a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh37a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh3 7a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh37a
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: so533 ld
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: so533 ld
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'b10 ohj' => 'B10 0HJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'b10 ohj' => 'B10 0HJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wit 4tp
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wit 4tp
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ni 9jy' => 'N1 9JY'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ni 9jy' => 'N1 9JY'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'hg3 ipy' => 'HG3 1PY'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'hg3 ipy' => 'HG3 1PY'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh3 7a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh37a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: le11 3x2
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: le113x2
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wc1 n1by
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wit 4tp
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wit 4tp
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wit 4tp
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wit 4tp
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wit 4tp
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wit 4tp
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'y010 5dg' => 'YO10 5DG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'y010 5dg' => 'YO10 5DG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'm27 50a' => 'M27 5OA'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'm27 50a' => 'M27 5OA'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'hg3 ipy' => 'HG3 1PY'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'hg3 ipy' => 'HG3 1PY'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wc1 n1by
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'b10 ohj' => 'B10 0HJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'b10 ohj' => 'B10 0HJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'b10 ohj' => 'B10 0HJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'b10 ohj' => 'B10 0HJ'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: kt22 75a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: kt2275a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ph2 8 dg
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: s21 1 tz
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wit 4tp
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wit 4tp
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ne3 3 ls
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ls10 ibl' => 'LS10 1BL'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ls10 ibl' => 'LS10 1BL'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'cb25 olq' => 'CB25 0LQ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'cb25 olq' => 'CB25 0LQ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: b18 6e
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: b186e
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'hg3 ipy' => 'HG3 1PY'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'hg3 ipy' => 'HG3 1PY'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ig10 4 lt
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nr7 ohr' => 'NR7 0HR'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nr7 ohr' => 'NR7 0HR'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 's031 4ra' => 'SO31 4RA'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 's031 4ra' => 'SO31 4RA'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'cw10 ohx' => 'CW10 0HX'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'cw10 ohx' => 'CW10 0HX'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'cw10 ohx' => 'CW10 0HX'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'cw10 ohx' => 'CW10 0HX'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wit 4tp
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wit 4tp
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wit 4tp
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wit 4tp
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: s14 qf
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: so533 ld
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: w1b 2h
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: w1b2h
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wit 4tp
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wit 4tp
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh3 7a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh37a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wit 4tp
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: wit 4tp
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: kt22 75a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: kt2275a
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'hg3 ipy' => 'HG3 1PY'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'hg3 ipy' => 'HG3 1PY'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 's0167np' => 'SO16 7NP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 's0167np' => 'SO16 7NP'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: e845l
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: e845l
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'hg3 ipy' => 'HG3 1PY'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'hg3 ipy' => 'HG3 1PY'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'y010 5dg' => 'YO10 5DG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'y010 5dg' => 'YO10 5DG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'y010 5dg' => 'YO10 5DG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'y010 5dg' => 'YO10 5DG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'cb25 olq' => 'CB25 0LQ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'cb25 olq' => 'CB25 0LQ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ni 4sd' => 'N1 4SD'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ni 4sd' => 'N1 4SD'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh3 7a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: eh37a
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 's031 4ra' => 'SO31 4RA'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 's031 4ra' => 'SO31 4RA'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'y010 5dg' => 'YO10 5DG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'y010 5dg' => 'YO10 5DG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 's031 4ra' => 'SO31 4RA'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 's031 4ra' => 'SO31 4RA'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'b10 ohj' => 'B10 0HJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'b10 ohj' => 'B10 0HJ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'y010 5dg' => 'YO10 5DG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'y010 5dg' => 'YO10 5DG'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: kt22 75a
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: kt2275a
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'm27 50a' => 'M27 5OA'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'm27 50a' => 'M27 5OA'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ox3 obp' => 'OX3 0BP'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '0x11 0de' => 'OX11 0DE'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'cb25 olq' => 'CB25 0LQ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'cb25 olq' => 'CB25 0LQ'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'nw1 otu' => 'NW1 0TU'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'wc1h oxg' => 'WC1H 0XG'
# ...
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 02467
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 753 23
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 75323
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 1190
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 1190
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 602 0841
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 6020841
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 28359
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 28359
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 600004
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 600004
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: d38106
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'd3810' => 'D3 8IO'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: f63177
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: f63177
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'i62100' => 'I62 1OO'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'i62100' => 'I62 1OO'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 3000
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 3000
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 220606201
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '06201' => 'O6 2OI'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: d96045
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: d96045
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 50100
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 50100
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 20690
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 20690
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 695001
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 695001
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 100088
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 100088
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 1202
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 1202
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 11074
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 11074
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '01510' => 'O1 5IO'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '01510' => 'O1 5IO'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: nsw 2351
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: nsw2351
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: k1n 7g2
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: k1n7g2
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: d30559
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: d30559
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 518057
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 518057
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 08007
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 08007
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 2153
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 2153
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 5651 cd
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 5651cd
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ch4003
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ch4003
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 110003
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '11000' => 'I1 0OO'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unspecified
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'ecified' => 'EC1F 1ED'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 770823101
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: '082310' => 'O82 3IO'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ut 84604
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: ut84604
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: fl 32310
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'fl32310' => 'FL32 3IO'
# INFO:uk-postcodes-parsing.ukpostcode:Postcode Fixed: 'fl32310' => 'FL32 3IO'
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: unknown
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: nsw 1230
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: nsw1230
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: 190006

# %%
ukpostcode.Postcode.__dict__
# Out:
# mappingproxy({'__module__': 'uk_postcodes_parsing.ukpostcode',
#               '__annotations__': {'is_in_ons_postcode_directory': bool,
#                'fix_distance': int,
#                'original': str,
#                'postcode': str,
#                'incode': str,
#                'outcode': str,
#                'area': str,
#                'district': str,
#                'sub_district': typing.Optional[str],
#                'sector': str,
#                'unit': str},
#               '__doc__': 'Class to hold the parsed postcode.\n    Constructor arguments:\n        original (str): The raw (original) string of the postcode.\n        postcode (str): The postcode as a string.\n        incode (str): The inward code (the first 3 characters) of the postcode.\n        outcode (str): The outward code (the last 4 characters) of the postcode.\n        area (str): The area of the postcode.\n        district (str): The district of the postcode.\n        sub_district (str): The sub-district of the postcode.\n        sector (str): The sector of the postcode.\n        unit (str): The unit of the postcode.\n\n    Additional attributes:\n        is_in_ons_postcode_directory (bool): Whether the postcode was successfully verified against\n            [ONS Postcode Directory](https://geoportal.statistics.gov.uk/datasets/489c152010a3425f80a71dc3663f73e1/about).\n        fix_distance (int): The number of characters that the postcode string was corrected by the\n            `fix` function during parsing.\n    ',
#               '__post_init__': <function uk_postcodes_parsing.ukpostcode.Postcode.__post_init__(self)>,
#               '__eq__': <function uk_postcodes_parsing.ukpostcode.Postcode.__eq__(self, other)>,
#               '__dict__': <attribute '__dict__' of 'Postcode' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Postcode' objects>,
#               '__hash__': None,
#               '__dataclass_params__': _DataclassParams(init=True,repr=True,eq=True,order=True,unsafe_hash=False,frozen=False),
#               '__dataclass_fields__': {'is_in_ons_postcode_directory': Field(name='is_in_ons_postcode_directory',type=<class 'bool'>,default=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,default_factory=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,init=False,repr=True,hash=None,compare=True,metadata=mappingproxy({}),kw_only=False,_field_type=_FIELD),
#                'fix_distance': Field(name='fix_distance',type=<class 'int'>,default=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,default_factory=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,init=False,repr=True,hash=None,compare=True,metadata=mappingproxy({}),kw_only=False,_field_type=_FIELD),
#                'original': Field(name='original',type=<class 'str'>,default=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,default_factory=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,init=True,repr=True,hash=None,compare=True,metadata=mappingproxy({}),kw_only=False,_field_type=_FIELD),
#                'postcode': Field(name='postcode',type=<class 'str'>,default=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,default_factory=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,init=True,repr=True,hash=None,compare=True,metadata=mappingproxy({}),kw_only=False,_field_type=_FIELD),
#                'incode': Field(name='incode',type=<class 'str'>,default=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,default_factory=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,init=True,repr=True,hash=None,compare=True,metadata=mappingproxy({}),kw_only=False,_field_type=_FIELD),
#                'outcode': Field(name='outcode',type=<class 'str'>,default=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,default_factory=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,init=True,repr=True,hash=None,compare=True,metadata=mappingproxy({}),kw_only=False,_field_type=_FIELD),
#                'area': Field(name='area',type=<class 'str'>,default=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,default_factory=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,init=True,repr=True,hash=None,compare=True,metadata=mappingproxy({}),kw_only=False,_field_type=_FIELD),
#                'district': Field(name='district',type=<class 'str'>,default=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,default_factory=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,init=True,repr=True,hash=None,compare=True,metadata=mappingproxy({}),kw_only=False,_field_type=_FIELD),
#                'sub_district': Field(name='sub_district',type=typing.Optional[str],default=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,default_factory=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,init=True,repr=True,hash=None,compare=True,metadata=mappingproxy({}),kw_only=False,_field_type=_FIELD),
#                'sector': Field(name='sector',type=<class 'str'>,default=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,default_factory=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,init=True,repr=True,hash=None,compare=True,metadata=mappingproxy({}),kw_only=False,_field_type=_FIELD),
#                'unit': Field(name='unit',type=<class 'str'>,default=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,default_factory=<dataclasses._MISSING_TYPE object at 0x7c39317200d0>,init=True,repr=True,hash=None,compare=True,metadata=mappingproxy({}),kw_only=False,_field_type=_FIELD)},
#               '__init__': <function uk_postcodes_parsing.ukpostcode.Postcode.__init__(self, original: str, postcode: str, incode: str, outcode: str, area: str, district: str, sub_district: Optional[str], sector: str, unit: str) -> None>,
#               '__repr__': <function uk_postcodes_parsing.ukpostcode.Postcode.__repr__(self)>,
#               '__lt__': <function uk_postcodes_parsing.ukpostcode.Postcode.__lt__(self, other)>,
#               '__le__': <function uk_postcodes_parsing.ukpostcode.Postcode.__le__(self, other)>,
#               '__gt__': <function uk_postcodes_parsing.ukpostcode.Postcode.__gt__(self, other)>,
#               '__ge__': <function uk_postcodes_parsing.ukpostcode.Postcode.__ge__(self, other)>,
#               '__match_args__': ('original',
#                'postcode',
#                'incode',
#                'outcode',
#                'area',
#                'district',
#                'sub_district',
#                'sector',
#                'unit')})

# %%
good_code = "SW1A 1AA"
bad_code = "w1 t 5 hd"

def remove_whitespace(postcode):
    return re.sub(r"\s+", "", postcode)

# %%
parsed = parse_postcode(good_code)
parsed
# Out:
# {'original': 'SW1A 1AA',
#  'postcode': 'SW1A 1AA',
#  'incode': '1AA',
#  'outcode': 'SW1A',
#  'area': 'SW',
#  'district': 'SW1',
#  'sub_district': 'SW1A',
#  'sector': 'SW1A 1',
#  'unit': 'AA',
#  'fix_distance': 0,
#  'is_in_ons_postcode_directory': True}

# %%
parsed = parse_postcode(bad_code)
parsed

# %%
ukpostcode.parse(bad_code)
# Out:
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: w1 t 5 hd

# %%
ukpostcode.parse(remove_whitespace(bad_code))
# Out:
# Postcode(is_in_ons_postcode_directory=True, fix_distance=0, original='w1t5hd', postcode='W1T 5HD', incode='5HD', outcode='W1T', area='W', district='W1', sub_district='W1T', sector='W1T 5', unit='HD')

# %%
parsed =ukpostcode.parse_from_corpus(bad_code, attempt_fix=True, try_all_fix_options=True)
parsed[1].__dict__
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 parsed =ukpostcode.parse_from_corpus(bad_code, attempt_fix=True, try_all_fix_options=True)
# ----> 2 parsed[1].__dict__
#
# IndexError: list index out of range

# %%
good_code = "SW1A 1AA"
bad_code = "w1 t 5 hd"

def remove_whitespace(postcode):
    return re.sub(r"\s+", "", postcode)

def postcode_parser(postcode):
    parsed = try_parsing(postcode)
    if parsed:
        return parsed
    parsed = try_parsing(remove_whitespace(postcode))
    return parsed

        
def try_parsing(postcode):
    try:
        parsed = a(postcode)
        if parsed:
            return parsed
    except Exception as e:
        pass
    try:
        parsed = b(postcode)
        if parsed:
            return parsed
    except Exception as e:
        pass
    try:
        parsed = c(postcode)
        if parsed:
            return parsed
    except Exception as e:
        pass
    else:
        return None

def a(postcode):
    try:
        parsed = ukpostcode.parse(postcode)
        return parsed[0].__dict__
    except Exception as e:
        pass
    else:
        return None
    
def b(postcode):
    try:
        parsed = ukpostcode.parse_from_corpus(postcode, attempt_fix=True)
        return parsed[0].__dict__
    except Exception as e:
        pass
    else:
        return None
    
def c(postcode):
    try:
        parsed = ukpostcode.parse_from_corpus(postcode, attempt_fix=True, try_all_fix_options=True)
        return parsed[0].__dict__
    except Exception as e:
        pass
    else:
        return None

parsed = postcode_parser("bloo")
# Out:
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: bloo
# ERROR:uk-postcodes-parsing.ukpostcode:Unable to fix postcode
# ERROR:uk-postcodes-parsing.ukpostcode:Failed to parse postcode: bloo

# %%
print(parsed)
# Out:
# None

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 parsed[0].__dict__
#
# KeyError: 0
